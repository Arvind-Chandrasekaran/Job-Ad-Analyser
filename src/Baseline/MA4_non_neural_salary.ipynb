# %% [markdown]
# Import data from Google Drive

# %%
import os
from google.colab import drive

drive.mount('/content/drive')
folder_path = '/content/drive/MyDrive/AB_job_data_files'

import os
from google.colab import drive

# find location of different files:
file_location = {}
# Check if the folder exists
if os.path.exists(folder_path):
  os.chdir(folder_path)
  for num, f in enumerate(os.listdir()):  # List files and directories in the current folder
    file_location[f] = os.path.join(folder_path, f)

else:
  print(f"Folder not found: {folder_path}")

print(file_location)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# {'seniority_labelled_test_set.csv': '/content/drive/MyDrive/AB_job_data_files/seniority_labelled_test_set.csv', 'unlabelled_development_set.csv': '/content/drive/MyDrive/AB_job_data_files/unlabelled_development_set.csv', 'salary_labelled_development_set.csv': '/content/drive/MyDrive/AB_job_data_files/salary_labelled_development_set.csv', 'seniority_labelled_development_set.csv': '/content/drive/MyDrive/AB_job_data_files/seniority_labelled_development_set.csv', 'work_arrangements_test_set.csv': '/content/drive/MyDrive/AB_job_data_files/work_arrangements_test_set.csv', 'salary_labelled_test_set.csv': '/content/drive/MyDrive/AB_job_data_files/salary_labelled_test_set.csv', 'work_arrangements_development_set.csv': '/content/drive/MyDrive/AB_job_data_files/work_arrangements_development_set.csv', 'results': '/content/drive/MyDrive/AB_job_data_files/results', 'wandb': '/content/drive/MyDrive/AB_job_data_files/wandb', 't5-small-work-arrangement-finetuned': '/content/drive/MyDrive/AB_job_data_files/t5-small-work-arrangement-finetuned', 'model_save': '/content/drive/MyDrive/AB_job_data_files/model_save', 'T5-small-non-fine-tuned-workarrangements_dev.csv': '/content/drive/MyDrive/AB_job_data_files/T5-small-non-fine-tuned-workarrangements_dev.csv', 'T5-small-non-fine-tuned-workarrangements_test.csv': '/content/drive/MyDrive/AB_job_data_files/T5-small-non-fine-tuned-workarrangements_test.csv'}

# %% [markdown]
# Create a function to extract salary

# %%
import spacy
import re

# Load the spaCy model
nlp = spacy.load("en_core_web_sm")

def extract_salary(text):
    """
    Extracts salary information from text using spaCy and regular expressions.

    Args:
        text: The input text string.

    Returns:
        A list of strings, each representing a detected salary in the format:
        minsalary-maxsalary-currency-frequency
    """
    doc = nlp(text)
    salaries_higher_confidence = []
    salaries_lower_confidence = []

    currency_pattern = r"\$|£|€|USD|GBP|EUR|AUD|MYR|SGD|PHP|NZD|k|K"
    range_pattern = r"(?:between|from)\s*[\d,.]+[kK]?\s*(?:(?:-|to)\s*[\d,.]+[kK]?)?|\d{1,3}(?:,\d{3})*(?:\.\d+)?[kK]?"

    # Two methods will be used to look for salary:

    # Method 1: Use inbuilt functions to look for MONEY and CARDINAL labels.
    for ent in doc.ents:

        # If any money is detected then add it to salary
        if ent.label_ in ["MONEY"]:
            salaries_higher_confidence.append(ent.text)

        # If any number is detected then to improve the accuracy, a second pass is added.
        elif ent.label_ in ["CARDINAL"]:
            if re.search(currency_pattern, ent.text) or re.search(range_pattern, ent.text):
                salaries_higher_confidence.append(ent.text)

    # Method 2: Check for potential salaries outside entities
    for token in doc:
        if token.pos_ in ["NUM", "SYM"] and re.search(currency_pattern, token.text):  # Check for currency symbols
            salaries_lower_confidence.append(token.text)
        elif token.pos_ == "NUM" and re.search(range_pattern, token.text):  # Check for numerical ranges
            salaries_lower_confidence.append(token.text)
        elif token.dep_ in ["nummod", "nmod"] and token.head.text.lower() in ["salary", "wage", "pay"]:
            # Check for numerical modifiers of salary-related words
            potential_salary = token.text
            if token.head.text.lower() in ["salary", "wage", "pay"]:
                salaries_lower_confidence.append(potential_salary)
        # Check for numbers ending with "K"
        elif token.pos_ == "NUM" and (token.text.endswith("k") or token.text.endswith("K")):
            salaries_lower_confidence.append(token.text)

    # 1: change k|K to 000
    salaries_higher_confidence = [salary.replace('k', '000').replace('K', '000') for salary in salaries_higher_confidence if salary]
    salaries_lower_confidence = [salary.replace('k', '000').replace('K', '000') for salary in salaries_lower_confidence if salary]

    # 2: Remove non-numeric characters (except comma, hyphen, "to", and "between")
    updated_salaries = []
    for salary in salaries_lower_confidence:
        modified_salary = re.sub(r"[^0-9,\-tobetween]", "", salary)  # Keep commas, hyphens, "to", and "between"
        updated_salaries.append(modified_salary)
    salaries_lower_confidence = updated_salaries

    updated_salaries = []
    for salary in salaries_higher_confidence:
        modified_salary = re.sub(r"[^0-9\-tobetween]", "", salary)  # Keep commas, hyphens, "to", and "between"
        updated_salaries.append(modified_salary)
    salaries_higher_confidence = updated_salaries

    # select appropriate salary
    selected_salary = None

    # Step 1: Check for range formats in higher confidence salaries
    if any(any(keyword in salary for keyword in ['-', 'to', 'between']) for salary in salaries_higher_confidence):
        selected_salary = next((salary for salary in salaries_higher_confidence if any(keyword in salary for keyword in ['-', 'to', 'between'])), None)
        selected_salary = f"{selected_salary}"

    # Step 2: If there are any numeric salaries in higher confidence
    elif salaries_higher_confidence:
        try:
            numeric_salaries = [int(s.replace(',', '')) for s in salaries_higher_confidence if s.replace(',', '').replace('.', '').isdigit()]
            if numeric_salaries:
                selected_salary = f"{min(numeric_salaries)}-{max(numeric_salaries)}"
        except ValueError:
            pass

    # Step 3: If there are any numeric salaries in lower confidence
    elif salaries_lower_confidence:
        try:
            numeric_salaries = [int(s.replace(',', '')) for s in salaries_lower_confidence if s.replace(',', '').replace('.', '').isdigit()]
            if numeric_salaries:
                selected_salary = f"{min(numeric_salaries)}-{max(numeric_salaries)}"
        except ValueError:
            pass

    # Step 4: Default fallback
    if not selected_salary:
        return "0-0-None-None"


    # Extract min and max salary (if range is present)
    parts = re.split(r"-|to_between", selected_salary)  # Split by "-" or "to"
    min_salary = parts[0].strip()
    max_salary = parts[1].strip() if len(parts) > 1 else parts[0].strip()  # If no max, use min

    # Extract currency (using regex) - assumption order: $ £ €
    currency_match = re.search(r"\$|£|€|USD|GBP|EUR|AUD|MYR|SGD|PHP|NZD", salary)
    currency = currency_match.group(0) if currency_match else "USD"  # Default to USD

    # Extract frequency (looking for keywords)
    frequency = "YEARLY"  # Default to yearly
    if "month" in salary.lower() or "monthly" in salary.lower():
        frequency = "MONTHLY"
    elif "hour" in salary.lower() or "hourly" in salary.lower():
        frequency = "HOURLY"

    # Format the output string
    formatted_salary = f"{min_salary}-{max_salary}-{currency}-{frequency}"

    # print('formatted salaries', formatted_salary)
    return formatted_salary

# %% [markdown]
# Test example

# %%
# Example usage

text = """<div><div><div>

 Job Opening

 <p>
 Financial Account - Call Center Agent - Up to $34k
 </p>
 </div></div></div>
<div><div></div></div>
<div><div><div>

 Job Industry


 <p>
 Telecommunications </p>
 </div></div></div>
<div><div></div></div>
<div><div><div>

 Job Type

 <p>
 Full-Time </p>
 </div></div></div>
<div><div></div></div>
<div><div><div>

 Experience Level


 <p>
 Entry Level </p>
 </div></div></div>
<div><div></div></div>
<div><div><div>

 Date Posted

 <p>
 2022-10-27 </p>
 </div></div></div>
<div><div></div></div>
<div><div><div>

 Job Location

 <p>
 Pasig BlvdPasig1000NCRPhilippines </p>
 </div></div></div>
<div><div></div></div>
<div><div><div>

 Company Information

 <p>
 Sapient

 Pasig Blvd
 Cebu, Central Visayas
 6019
 Sapient is Philippine-based BPO that provides a range of outsourcing services from consulting services, IT-enabled services, and call center services primarily catering small and medium based enterprises.
 </p>
 </div></div></div>
<div><div></div></div>
<div><div><div>

 Job Description

 <div>
<p>Job Responsibilities:</p>
<ul>
<li>Answers phone calls and provides important information/ assistance to clients</li>
<li>Checks mail, fax and internet mail to provide customer assistance</li>
<li>Communicates with customer on the phone or using written correspondence to take care of concerns</li>
<li>Answer participant questions, , as well as talk to participants to achieve full understanding of what critical information are being asked.</li>
</ul>
</div>
 </div></div></div>
<div><div></div></div>
<div><div><div>

 Job Qualifications

 <div>
<p>What are we looking for? Â  Â  Â  Â </p>
<ul>
<li>Open to candidates who completed college</li>
<li>Open to</li>
</ul>
<p>High School and Senior High School Graduates with BPO experience</p>
<ul>
<li>Excellent to above average English communication skills</li>
<li>BPO experience of at least 6 months or have work experience</li>
<li>Can do onsite work</li>
<li>With in 25km to 35 km</li>
</ul>
</div>
 </div></div></div>
<div><div></div></div>
<div><div><div>

 Compensation

 <p>
 17500 </p>
 </div></div></div>
<div><div></div></div>
<div><div><div>

 Compensation Range

 <p>
 â‚±15,000 - â‚±20,000 </p>
 </div></div></div>
<div><div></div></div>
<div><div></div></div>
<div><div></div></div>"""

salary_info = extract_salary(text)

print(salary_info)
# Out:
# 15000-20000-USD-YEARLY

# %% [markdown]
# Testing on Development Set for salary extraction

# %%
# DEV set
import pandas as pd
salary_dev = pd.read_csv(file_location['salary_labelled_development_set.csv'])

results = 0
count = 0

for index, row in salary_dev.iterrows(): # Iterate through the rows of the dataframe
    predicted_label = extract_salary(row['job_ad_details'])
    true_label =  row['y_true']

    print(predicted_label, '----', true_label)
    print(predicted_label == true_label)
    if predicted_label == true_label:
        results += 1
    count += 1

print("count:", count)
print("result:", results)
print("correctly indentified:", results/count)
# Out:
# 17500-34000-USD-YEARLY ---- 17500-17500-PHP-MONTHLY
# False
# 5-10-USD-YEARLY ---- 16000-16000-PHP-MONTHLY
# False
# 200-200-USD-YEARLY ---- 0-0-None-None
# False
# 1-5-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 1-8621-USD-YEARLY ---- 50-60-HKD-HOURLY
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 20000-20000-USD-YEARLY ---- 16000-16000-PHP-MONTHLY
# False
# 2-20000-USD-YEARLY ---- 17500-17500-PHP-MONTHLY
# False
# 6-3200-USD-YEARLY ---- 32-32-NZD-HOURLY
# False
# 3200tonton-3200tonton-USD-YEARLY ---- 2800-3200-MYR-MONTHLY
# False
# 13-23-USD-YEARLY ---- 65-65-HKD-HOURLY
# False
# 28-30-$-YEARLY ---- 28-30-NZD-HOURLY
# False
# 700-700-USD-YEARLY ---- 0-0-None-None
# False
# 8-8-USD-YEARLY ---- 0-0-None-None
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 2023-2023-USD-YEARLY ---- 35-35-AUD-HOURLY
# False
# 6000-6000-USD-YEARLY ---- 6000-6000-MYR-MONTHLY
# False
# 35-24-USD-YEARLY ---- 65-75-HKD-HOURLY
# False
# 8426-8426-USD-YEARLY ---- 0-0-None-None
# False
# 30-2022-USD-YEARLY ---- 0-0-None-None
# False
# 2-100-USD-YEARLY ---- 0-0-None-None
# False
# 2-27122023-USD-YEARLY ---- 100-100-HKD-HOURLY
# False
# 2302-2302-USD-YEARLY ---- 0-0-None-None
# False
# 4-4-USD-YEARLY ---- 0-0-None-None
# False
# 3-2008-USD-YEARLY ---- 1700-3500-MYR-MONTHLY
# False
# 13-275257-USD-YEARLY ---- 0-0-None-None
# False
# 200612189-200612189-USD-YEARLY ---- 0-0-None-None
# False
# 6735732-9456844-USD-YEARLY ---- 67357-94568-AUD-ANNUAL
# False
# 19-19-USD-YEARLY ---- 0-0-None-None
# False
# 4000-6000ont-USD-YEARLY ---- 4000-6000-SGD-MONTHLY
# False
# 65-1300-USD-YEARLY ---- 0-0-None-None
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 7-5-USD-YEARLY ---- 31-32-AUD-HOURLY
# False
# between100000n150000e-between100000n150000e-USD-YEARLY ---- 80000-85000-AUD-ANNUAL
# False
# 61-486486-USD-YEARLY ---- 0-0-None-None
# False
# 19-19-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 2200-2200-USD-YEARLY ---- 1800-2200-MYR-MONTHLY
# False
# 3-2021-USD-YEARLY ---- 0-0-None-None
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 10-20000-USD-YEARLY ---- 18000-18000-PHP-MONTHLY
# False
# 67to133owne-67to133owne-$-YEARLY ---- 67-133-HKD-DAILY
# False
# tet3-5-USD-YEARLY ---- 0-0-None-None
# False
# 1-1-USD-YEARLY ---- 0-0-None-None
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 8-8-USD-YEARLY ---- 0-0-None-None
# False
# 1500-1500-USD-YEARLY ---- 0-0-None-None
# False
# 530ton-530ton-USD-YEARLY ---- 950-1125-HKD-WEEKLY
# False
# 2-2-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 1000-1375-USD-YEARLY ---- 4000-5500-SGD-WEEKLY
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 55-55-USD-YEARLY ---- 0-0-None-None
# False
# 21-50000-USD-YEARLY ---- 0-0-None-None
# False
# 13105-13105-USD-YEARLY ---- 0-0-None-None
# False
# 8000-46435635-USD-YEARLY ---- 65-80-HKD-HOURLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 3-3-USD-YEARLY ---- 4000-5600-MYR-MONTHLY
# False
# 19-19-USD-YEARLY ---- 0-0-None-None
# False
# 50-50-USD-YEARLY ---- 50-60-HKD-HOURLY
# False
# 0-0-None-None ---- 5000-8000-MYR-MONTHLY
# False
# 1-1000-USD-YEARLY ---- 12-12-SGD-HOURLY
# False
# 3-6193-USD-YEARLY ---- 0-0-None-None
# False
# 18-28-USD-YEARLY ---- 1500-2500-MYR-MONTHLY
# False
# 20-30-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# 1-4-USD-YEARLY ---- 85000-100000-AUD-ANNUAL
# False
# 1-3-$-YEARLY ---- 52-55-HKD-HOURLY
# False
# 8810-8810-USD-YEARLY ---- 0-0-None-None
# False
# 34-23-USD-YEARLY ---- 88-88-HKD-HOURLY
# False
# 6297ton-6297ton-USD-YEARLY ---- 41-41-AUD-HOURLY
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 4-5-USD-YEARLY ---- 0-0-None-None
# False
# 36-24-USD-YEARLY ---- 60-70-HKD-HOURLY
# False
# 5-2958-USD-YEARLY ---- 0-0-None-None
# False
# 1889-1889-USD-YEARLY ---- 0-0-None-None
# False
# 2-2-USD-YEARLY ---- 0-0-None-None
# False
# 8907-8907-USD-YEARLY ---- 0-0-None-None
# False
# between3724to8397eo-between3724to8397eo-$-HOURLY ---- 37-84-AUD-HOURLY
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 010-3938581ton-USD-YEARLY ---- 1500-1800-MYR-MONTHLY
# False
# 1-54-USD-YEARLY ---- 0-0-None-None
# False
# 22-17000-USD-YEARLY ---- 0-0-None-None
# False
# 5-86-USD-YEARLY ---- 0-0-None-None
# False
# 3180-6217-USD-YEARLY ---- 0-0-None-None
# False
# 6-1-$-YEARLY ---- 32-34-AUD-HOURLY
# False
# 8-8-USD-YEARLY ---- 0-0-None-None
# False
# 22-24-USD-YEARLY ---- 60-75-HKD-HOURLY
# False
# 6-40-USD-YEARLY ---- 40-40-AUD-HOURLY
# False
# 1-43000-USD-YEARLY ---- 1800-3500-MYR-MONTHLY
# False
# 5-40-USD-YEARLY ---- 30-35-NZD-HOURLY
# False
# 1000-1000-USD-YEARLY ---- 1000-1000-THB-HOURLY
# False
# 3010-3010-USD-YEARLY ---- 3010-3010-SGD-MONTHLY
# False
# 725-725-USD-YEARLY ---- 0-0-None-None
# False
# 247oeton-247oeton-USD-YEARLY ---- 0-0-None-None
# False
# 6-6-$-HOURLY ---- 18-25-AUD-HOURLY
# False
# tet10-12e-USD-YEARLY ---- 0-0-None-None
# False
# 6-2024-USD-YEARLY ---- 0-0-None-None
# False
# 6-6-USD-YEARLY ---- 0-0-None-None
# False
# 21-7500-USD-YEARLY ---- 65-75-HKD-HOURLY
# False
# 3-300-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# 12-12-USD-YEARLY ---- 500-667-PHP-DAILY
# False
# 65-65-USD-YEARLY ---- 45-65-HKD-HOURLY
# False
# 1-1-USD-YEARLY ---- 1800-2000-MYR-MONTHLY
# False
# 4-120235140-USD-YEARLY ---- 70-75-HKD-HOURLY
# False
# 2500-3500-USD-YEARLY ---- 2500-3500-MYR-MONTHLY
# False
# 8-8-USD-YEARLY ---- 0-0-None-None
# False
# 1-2-USD-YEARLY ---- 0-0-None-None
# False
# 830-63640545-USD-YEARLY ---- 16000-16000-HKD-MONTHLY
# False
# 8-8-USD-YEARLY ---- 0-0-None-None
# False
# 3-1800-USD-YEARLY ---- 1500-1800-MYR-MONTHLY
# False
# 10-6-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# 17500-20000-USD-YEARLY ---- 17500-17500-PHP-MONTHLY
# False
# 7122023-7122023-USD-YEARLY ---- 60-60-HKD-HOURLY
# False
# 21-2958-USD-YEARLY ---- 0-0-None-None
# False
# 7762375--USD-YEARLY ---- 77624-79459-AUD-ANNUAL
# False
# to3400-to3400-USD-YEARLY ---- 3400-3400-SGD-MONTHLY
# False
# 1-105093-USD-YEARLY ---- 105093-108612-AUD-ANNUAL
# False
# 5-3467-USD-YEARLY ---- 0-0-None-None
# False
# 4-2023-USD-YEARLY ---- 2000-2000-MYR-MONTHLY
# False
# 8-8-USD-YEARLY ---- 0-0-None-None
# False
# 50-60-USD-YEARLY ---- 50-60-THB-HOURLY
# False
# 4-299275-USD-YEARLY ---- 0-0-None-None
# False
# 3-800-USD-YEARLY ---- 0-0-None-None
# False
# 1500-2330b-$-YEARLY ---- 16822-17618-HKD-MONTHLY
# False
# 30000-40000-USD-YEARLY ---- 30000-40000-THB-MONTHLY
# False
# 33-24-USD-YEARLY ---- 55-70-HKD-HOURLY
# False
# 3-15000-USD-YEARLY ---- 13000-13000-PHP-MONTHLY
# False
# 6-6-USD-YEARLY ---- 37000-37000-THB-MONTHLY
# False
# 24606189-24606189-USD-YEARLY ---- 0-0-None-None
# False
# 2024nbton-2024nbton-USD-YEARLY ---- 57000-62000-AUD-ANNUAL
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 1-1-USD-YEARLY ---- 30-30-AUD-HOURLY
# False
# 1-1500-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# 12-1982-USD-YEARLY ---- 2000-2000-MYR-MONTHLY
# False
# 0-0-None-None ---- 1500-2000-MYR-MONTHLY
# False
# 7004973-9835139e-USD-YEARLY ---- 70049-98351-AUD-ANNUAL
# False
# 1-45-USD-YEARLY ---- 0-0-None-None
# False
# 5-100-USD-YEARLY ---- 0-0-None-None
# False
# 625-625-USD-YEARLY ---- 625-725-HKD-WEEKLY
# False
# 15-15-USD-YEARLY ---- 0-0-None-None
# False
# 2050-2050-USD-YEARLY ---- 0-0-None-None
# False
# tet1to2e-tet1to2e-USD-YEARLY ---- 0-0-None-None
# False
# 4-9500-USD-YEARLY ---- 65-95-HKD-HOURLY
# False
# 2-120235140-USD-YEARLY ---- 120-200-HKD-HOURLY
# False
# 1-3-USD-YEARLY ---- 0-0-None-None
# False
# 2825-389140-USD-YEARLY ---- 23-28-NZD-HOURLY
# False
# tet1-e-USD-YEARLY ---- 0-0-None-None
# False
# 2500-3200tonton-USD-YEARLY ---- 2500-3200-SGD-MONTHLY
# False
# 42-1700-USD-YEARLY ---- 42-52-THB-HOURLY
# False
# 25-25-USD-YEARLY ---- 16000-16000-PHP-MONTHLY
# False
# 4-7-USD-YEARLY ---- 0-0-None-None
# False
# 1-900-USD-YEARLY ---- 25000-35000-THB-MONTHLY
# False
# to10000-to10000-USD-YEARLY ---- 128031-130582-AUD-ANNUAL
# False
# to30-to30-USD-YEARLY ---- 62525-64583-AUD-ANNUAL
# False
# 1-45001-USD-YEARLY ---- 0-0-None-None
# False
# 1-20000-USD-YEARLY ---- 17500-17500-PHP-MONTHLY
# False
# between30n35-between30n35-USD-YEARLY ---- 30-35-NZD-HOURLY
# False
# 2400-2400-USD-YEARLY ---- 2400-2600-SGD-MONTHLY
# False
# 22-24-USD-YEARLY ---- 70-70-HKD-HOURLY
# False
# 30-30-USD-YEARLY ---- 30-30-AUD-HOURLY
# False
# 40-5600-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# to15990-to15990-$-YEARLY ---- 26-26-AUD-HOURLY
# False
# 2460-2460-USD-YEARLY ---- 0-0-None-None
# False
# 1-20000-USD-YEARLY ---- 16000-16000-PHP-MONTHLY
# False
# 1-1159-USD-YEARLY ---- 0-0-None-None
# False
# 90000-130000-USD-YEARLY ---- 90000-130000-AUD-ANNUAL
# False
# 2200-2500tontonotonetenttontonbeontonobeonbtene-$-YEARLY ---- 2200-2500-SGD-MONTHLY
# False
# 7-1045-USD-YEARLY ---- 0-0-None-None
# False
# 2-3114870-USD-YEARLY ---- 30-30-AUD-HOURLY
# False
# 19-19-USD-YEARLY ---- 0-0-None-None
# False
# 10-10-USD-YEARLY ---- 0-0-None-None
# False
# 1-1-USD-YEARLY ---- 0-0-None-None
# False
# 5-120235140-USD-YEARLY ---- 65-80-HKD-HOURLY
# False
# 830-830-USD-YEARLY ---- 0-0-None-None
# False
# 2447-2447-USD-YEARLY ---- 24-24-AUD-HOURLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 15-247-USD-YEARLY ---- 25000-25000-PHP-MONTHLY
# False
# 12-1982-USD-YEARLY ---- 2000-2000-MYR-MONTHLY
# False
# 2-7-USD-YEARLY ---- 0-0-None-None
# False
# 1800-1800-USD-YEARLY ---- 0-0-None-None
# False
# 41-41-USD-YEARLY ---- 36-41-AUD-HOURLY
# False
# 50000-60000nb-USD-YEARLY ---- 40000-60000-THB-MONTHLY
# False
# 2500-2500-USD-YEARLY ---- 2500-3200-SGD-MONTHLY
# False
# 53-6000-USD-YEARLY ---- 50-60-AUD-HOURLY
# False
# 1023-1667-USD-YEARLY ---- 1000-1667-PHP-DAILY
# False
# to15900-to15900-$-YEARLY ---- 45-45-AUD-HOURLY
# False
# 2-8240-USD-YEARLY ---- 48-48-AUD-HOURLY
# False
# 10-10-USD-YEARLY ---- 0-0-None-None
# False
# 8-20000-USD-YEARLY ---- 16000-16000-PHP-MONTHLY
# False
# 2-2-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 0-0-None-None ---- 70000-70000-AUD-ANNUAL
# False
# 5033667-5522580-USD-YEARLY ---- 50337-55226-AUD-ANNUAL
# False
# 10-10-USD-YEARLY ---- 0-0-None-None
# False
# 25000-20125010-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 25000-30000-USD-YEARLY ---- 25000-25000-PHP-MONTHLY
# False
# 9-9-USD-YEARLY ---- 0-0-None-None
# False
# 17500-20000-USD-YEARLY ---- 17500-17500-PHP-MONTHLY
# False
# 1-240690-USD-YEARLY ---- 59113-62794-AUD-ANNUAL
# False
# to5000bb-to5000bb-USD-YEARLY ---- 127315-127315-AUD-ANNUAL
# False
# 77-93-USD-YEARLY ---- 77-93-HKD-DAILY
# False
# 1-4072-USD-YEARLY ---- 41-41-AUD-HOURLY
# False
# 2-2-USD-YEARLY ---- 0-0-None-None
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 1-5-USD-YEARLY ---- 0-0-None-None
# False
# 11-20000-USD-YEARLY ---- 16000-16000-PHP-MONTHLY
# False
# 515-830-USD-YEARLY ---- 2500-2800-SGD-MONTHLY
# False
# 22000-30000-USD-YEARLY ---- 22000-22000-PHP-MONTHLY
# False
# 2910-3011eo25-USD-YEARLY ---- 29-30-AUD-HOURLY
# False
# 30-30-USD-YEARLY ---- 28-30-NZD-HOURLY
# False
# 089-956-USD-YEARLY ---- 0-0-None-None
# False
# 3533-4960-USD-YEARLY ---- 35-50-AUD-HOURLY
# False
# 10-2551-USD-YEARLY ---- 0-0-None-None
# False
# 2497ton-2497ton-USD-YEARLY ---- 0-0-None-None
# False
# to105-to105-USD-YEARLY ---- 105-105-AUD-HOURLY
# False
# 07-15-USD-YEARLY ---- 17000-17000-PHP-MONTHLY
# False
# 70-4500-USD-YEARLY ---- 35-45-NZD-HOURLY
# False
# 22-22-USD-YEARLY ---- 0-0-None-None
# False
# 25-80-USD-YEARLY ---- 25-25-NZD-HOURLY
# False
# 38-38-USD-YEARLY ---- 41-41-AUD-HOURLY
# False
# 2300--$-YEARLY ---- 2300-3500-SGD-MONTHLY
# False
# 19-19-USD-YEARLY ---- 0-0-None-None
# False
# 247-247-USD-YEARLY ---- 0-0-None-None
# False
# to750-to750-USD-YEARLY ---- 50-50-AUD-HOURLY
# False
# 3-3-USD-YEARLY ---- 2100-2100-MYR-MONTHLY
# False
# 1700-863629665-USD-YEARLY ---- 12000-18000-THB-MONTHLY
# False
# 09-18-USD-YEARLY ---- 25000-25000-PHP-MONTHLY
# False
# 2-54-USD-YEARLY ---- 0-0-None-None
# False
# 77-110-$-YEARLY ---- 77-110-HKD-HOURLY
# False
# 11-6162-USD-YEARLY ---- 0-0-None-None
# False
# 12-1982-USD-YEARLY ---- 2000-2000-MYR-MONTHLY
# False
# 3-10-USD-YEARLY ---- 0-0-None-None
# False
# 1-129737175-USD-YEARLY ---- 1500-2500-MYR-MONTHLY
# False
# tet2-3e-USD-YEARLY ---- 3000-3500-SGD-MONTHLY
# False
# to160-to160-USD-YEARLY ---- 54-54-AUD-HOURLY
# False
# 2650-15900-USD-YEARLY ---- 34-34-AUD-HOURLY
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 2-2-USD-YEARLY ---- 0-0-None-None
# False
# 8348712-8348712-USD-YEARLY ---- 71838-83487-AUD-ANNUAL
# False
# 2-54-USD-YEARLY ---- 0-0-None-None
# False
# tet3-5e-USD-YEARLY ---- 4000-5000-MYR-MONTHLY
# False
# 400-500b-USD-YEARLY ---- 400-500-THB-HOURLY
# False
# 0-9393-USD-YEARLY ---- 70-70-HKD-HOURLY
# False
# 70-70-USD-YEARLY ---- 0-0-None-None
# False
# 1600-1600-USD-YEARLY ---- 1600-2200-MYR-MONTHLY
# False
# 23-23-USD-YEARLY ---- 63-63-HKD-HOURLY
# False
# 1-2024-USD-YEARLY ---- 1900-1900-MYR-MONTHLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 13-2024-USD-YEARLY ---- 63-63-MYR-DAILY
# False
# 1-2018-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 1-1-USD-YEARLY ---- 0-0-None-None
# False
# 70-25000-USD-YEARLY ---- 0-0-None-None
# False
# 19-19-USD-YEARLY ---- 0-0-None-None
# False
# 45-45-USD-YEARLY ---- 0-0-None-None
# False
# 19-19-USD-YEARLY ---- 0-0-None-None
# False
# 2-300-USD-YEARLY ---- 0-0-None-None
# False
# t-ono-USD-YEARLY ---- 0-0-None-None
# False
# 1-12387036-USD-YEARLY ---- 123870-127316-AUD-ANNUAL
# False
# 19-60000-USD-YEARLY ---- 60000-60000-AUD-ANNUAL
# False
# 1-3-USD-YEARLY ---- 2000-3000-MYR-MONTHLY
# False
# 2-6-USD-YEARLY ---- 12500-12500-PHP-MONTHLY
# False
# 2673-2673-USD-YEARLY ---- 27-30-AUD-HOURLY
# False
# 6398-9201-USD-YEARLY ---- 50-50-HKD-HOURLY
# False
# 2230-7981-USD-YEARLY ---- 0-0-None-None
# False
# 24-24-USD-YEARLY ---- 30-42-AUD-HOURLY
# False
# 1-100-USD-YEARLY ---- 0-0-None-None
# False
# 5-9-USD-YEARLY ---- 2800-3000-SGD-MONTHLY
# False
# 1-7500-USD-YEARLY ---- 70-75-HKD-HOURLY
# False
# 10-10-USD-YEARLY ---- 0-0-None-None
# False
# 8-9268-USD-YEARLY ---- 0-0-None-None
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 5-912918-USD-YEARLY ---- 0-0-None-None
# False
# 1-1-USD-YEARLY ---- 0-0-None-None
# False
# 630-1875-USD-YEARLY ---- 1250-1875-SGD-WEEKLY
# False
# 700-103915-USD-YEARLY ---- 103915-113267-AUD-ANNUAL
# False
# 2-14-USD-YEARLY ---- 14-14-SGD-HOURLY
# False
# 09-30-USD-YEARLY ---- 21000-21000-PHP-MONTHLY
# False
# to15899-to15899-USD-YEARLY ---- 48-50-AUD-HOURLY
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 10-2958-USD-YEARLY ---- 0-0-None-None
# False
# 10-15000o-USD-YEARLY ---- 30-30-AUD-HOURLY
# False
# 1-120235140-USD-YEARLY ---- 65-65-HKD-HOURLY
# False
# 133671-133671-USD-YEARLY ---- 133671-133671-AUD-ANNUAL
# False
# 3721-5392-$-YEARLY ---- 37-54-AUD-HOURLY
# False
# tet7-19-USD-YEARLY ---- 0-0-None-None
# False
# 330-530-USD-YEARLY ---- 30-31-AUD-HOURLY
# False
# 10-10-USD-YEARLY ---- 0-0-None-None
# False
# 2-26022025-USD-YEARLY ---- 270-270-HKD-HOURLY
# False
# 1-38-USD-YEARLY ---- 133671-159929-AUD-ANNUAL
# False
# 200to267tonton-200to267tonton-$-YEARLY ---- 200-267-SGD-DAILY
# False
# 7-29-USD-YEARLY ---- 500-667-PHP-DAILY
# False
# 13-23-USD-YEARLY ---- 60-60-HKD-HOURLY
# False
# 1-1-USD-YEARLY ---- 0-0-None-None
# False
# 2793-912918-USD-YEARLY ---- 0-0-None-None
# False
# 2-12-USD-YEARLY ---- 0-0-None-None
# False
# 2-8331-USD-YEARLY ---- 0-0-None-None
# False
# 12-15-$-YEARLY ---- 12-15-SGD-HOURLY
# False
# 9-9-USD-YEARLY ---- 9-12-MYR-HOURLY
# False
# 31-23-USD-YEARLY ---- 100-100-HKD-HOURLY
# False
# 70-25000-USD-YEARLY ---- 0-0-None-None
# False
# 600-600-USD-YEARLY ---- 0-0-None-None
# False
# 30000-4000040000-USD-YEARLY ---- 40000-60000-THB-MONTHLY
# False
# 81-81-USD-YEARLY ---- 0-0-None-None
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 5418-5418-USD-YEARLY ---- 24-54-AUD-HOURLY
# False
# 3-566930-USD-YEARLY ---- 0-0-None-None
# False
# 5000-7000-USD-YEARLY ---- 5000-7000-SGD-MONTHLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 73000-80000-$-YEARLY ---- 73000-80000-AUD-ANNUAL
# False
# 50-50-USD-YEARLY ---- 0-0-None-None
# False
# 7-20000-USD-YEARLY ---- 18000-18000-PHP-MONTHLY
# False
# 100150-100150-$-YEARLY ---- 100-150-HKD-HOURLY
# False
# 1-6453-USD-YEARLY ---- 0-0-None-None
# False
# 1800-2350-USD-YEARLY ---- 1800-2350-SGD-MONTHLY
# False
# to20-to20-USD-YEARLY ---- 7000-7000-MYR-MONTHLY
# False
# 3000-3000-USD-YEARLY ---- 3000-4000-SGD-MONTHLY
# False
# tet1-2e-USD-YEARLY ---- 2000-3000-SGD-MONTHLY
# False
# 9200-9200-USD-YEARLY ---- 8200-9200-SGD-MONTHLY
# False
# 4250-4250-USD-YEARLY ---- 42-42-AUD-HOURLY
# False
# 18-830-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# tetet5-8e-USD-YEARLY ---- 0-0-None-None
# False
# 12-12-USD-YEARLY ---- 33-33-AUD-HOURLY
# False
# 19-19-USD-YEARLY ---- 0-0-None-None
# False
# to5000-to5000-USD-YEARLY ---- 56896-83799-AUD-ANNUAL
# False
# 27-27-USD-YEARLY ---- 25-27-NZD-HOURLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 6-7-USD-YEARLY ---- 3750-5000-HKD-WEEKLY
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# to45-to45-$-YEARLY ---- 40-45-AUD-HOURLY
# False
# 1200-1200-USD-YEARLY ---- 0-0-None-None
# False
# 3-33-USD-YEARLY ---- 20-33-SGD-DAILY
# False
# 36-24-USD-YEARLY ---- 100-100-HKD-HOURLY
# False
# 1-2021-USD-YEARLY ---- 0-0-None-None
# False
# 1-3-USD-YEARLY ---- 0-0-None-None
# False
# 0-38-USD-YEARLY ---- 83988-83988-AUD-ANNUAL
# False
# 7-809-USD-YEARLY ---- 45-50-AUD-HOURLY
# False
# 0-0-None-None ---- 20-30-AUD-HOURLY
# False
# 14000-14000-USD-YEARLY ---- 0-0-None-None
# False
# 36550ton-36550ton-USD-YEARLY ---- 0-0-None-None
# False
# 1-2-USD-YEARLY ---- 0-0-None-None
# False
# to10000-to10000-USD-YEARLY ---- 70049-98351-AUD-ANNUAL
# False
# 8-5-USD-YEARLY ---- 1500-2200-MYR-MONTHLY
# False
# 2-7-USD-YEARLY ---- 0-0-None-None
# False
# 530tonton-530tonton-USD-YEARLY ---- 3800-5000-SGD-MONTHLY
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 10-15-USD-YEARLY ---- 0-0-None-None
# False
# 8469-8469-USD-YEARLY ---- 84-84-AUD-HOURLY
# False
# 15-15-USD-YEARLY ---- 0-0-None-None
# False
# 16592-16592-USD-YEARLY ---- 0-0-None-None
# False
# 830to1730-830to1730-USD-YEARLY ---- 18000-20000-THB-MONTHLY
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 3-7890-USD-YEARLY ---- 0-0-None-None
# False
# 3-5-USD-YEARLY ---- 0-0-None-None
# False
# 5-10-USD-YEARLY ---- 0-0-None-None
# False
# 8907-8907-USD-YEARLY ---- 0-0-None-None
# False
# 232024-232024-USD-YEARLY ---- 700-1000-SGD-WEEKLY
# False
# 11-4550-USD-YEARLY ---- 0-0-None-None
# False
# 25000-30000-USD-YEARLY ---- 25000-25000-PHP-MONTHLY
# False
# 1-38-USD-YEARLY ---- 119348-136057-AUD-ANNUAL
# False
# 0-0-None-None ---- 10000000-15000000-IDR-MONTHLY
# False
# 2500-3500-USD-YEARLY ---- 2500-3500-SGD-MONTHLY
# False
# 416126016-416126016-USD-YEARLY ---- 0-0-None-None
# False
# 17-612-USD-YEARLY ---- 120-120-HKD-HOURLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 3-3-USD-YEARLY ---- 25000-37000-THB-MONTHLY
# False
# 6252558-645835-USD-YEARLY ---- 62525-64583-AUD-ANNUAL
# False
# 3-1800-USD-YEARLY ---- 1500-1800-MYR-MONTHLY
# False
# 32-23-USD-YEARLY ---- 46-62-HKD-HOURLY
# False
# tet2to-tet2to-USD-YEARLY ---- 0-0-None-None
# False
# 1971-1971-USD-YEARLY ---- 0-0-None-None
# False
# 1188-2551-USD-YEARLY ---- 0-0-None-None
# False
# 3-140000-USD-YEARLY ---- 110000-140000-AUD-ANNUAL
# False
# 200-30000-USD-YEARLY ---- 25000-25000-PHP-MONTHLY
# False
# 21-2958-USD-YEARLY ---- 0-0-None-None
# False
# 8000-13000-USD-YEARLY ---- 1800-2500-MYR-MONTHLY
# False
# 2-40-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 2460-2460-USD-YEARLY ---- 0-0-None-None
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 700-700-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# 19-19-USD-YEARLY ---- 0-0-None-None
# False
# 400-900-USD-YEARLY ---- 0-0-None-None
# False
# 400-600-$-YEARLY ---- 400-600-HKD-WEEKLY
# False
# 1-et-USD-YEARLY ---- 0-0-None-None
# False
# between100000to140000-between100000to140000-$-YEARLY ---- 100000-140000-AUD-ANNUAL
# False
# 3-1800-USD-YEARLY ---- 1500-1800-MYR-MONTHLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 81-81-USD-YEARLY ---- 0-0-None-None
# False
# 10-10-USD-YEARLY ---- 0-0-None-None
# False
# 1-1-USD-YEARLY ---- 0-0-None-None
# False
# 3-3-USD-YEARLY ---- 15000-16000-PHP-MONTHLY
# False
# 7-8835-USD-YEARLY ---- 0-0-None-None
# False
# 2-2-USD-YEARLY ---- 0-0-None-None
# False
# 18-18-USD-YEARLY ---- 25-30-NZD-HOURLY
# False
# 23240063ton-23240063ton-USD-YEARLY ---- 0-0-None-None
# False
# 1188-2551-USD-YEARLY ---- 0-0-None-None
# False
# 6-1500-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# 6193-6193-USD-YEARLY ---- 0-0-None-None
# False
# 2-2-USD-YEARLY ---- 0-0-None-None
# False
# 25-25-USD-YEARLY ---- 0-0-None-None
# False
# 20000-30000-USD-YEARLY ---- 20000-30000-THB-MONTHLY
# False
# between2249-2825eo-$-HOURLY ---- 22-28-NZD-HOURLY
# False
# 1-1-USD-YEARLY ---- 110-110-HKD-HOURLY
# False
# 1200-1200-USD-YEARLY ---- 0-0-None-None
# False
# 30000-160000-USD-YEARLY ---- 0-0-None-None
# False
# 3-1800-USD-YEARLY ---- 1500-1800-MYR-MONTHLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 8-13-$-YEARLY ---- 8-13-SGD-HOURLY
# False
# ntteentton2500--$-YEARLY ---- 2500-3400-SGD-MONTHLY
# False
# 4000-4000-USD-YEARLY ---- 3300-4000-MYR-MONTHLY
# False
# 6-6-USD-YEARLY ---- 0-0-None-None
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 5-52-USD-YEARLY ---- 0-0-None-None
# False
# 5-20-USD-YEARLY ---- 25000-25000-THB-MONTHLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 3-2958-USD-YEARLY ---- 0-0-None-None
# False
# 67--USD-YEARLY ---- 67-100-SGD-DAILY
# False
# 50-50-USD-YEARLY ---- 0-0-None-None
# False
# 1-125151-USD-YEARLY ---- 102051-125151-AUD-ANNUAL
# False
# 4-11-USD-YEARLY ---- 12-12-SGD-HOURLY
# False
# 19-19-USD-YEARLY ---- 0-0-None-None
# False
# 10-2010-USD-YEARLY ---- 0-0-None-None
# False
# 117-143-$-YEARLY ---- 117-143-PHP-DAILY
# False
# 225-1200-USD-YEARLY ---- 875-1200-HKD-WEEKLY
# False
# 1-12-USD-YEARLY ---- 1600-1800-MYR-MONTHLY
# False
# 700to875-700to875-$-YEARLY ---- 700-875-SGD-WEEKLY
# False
# 81-81-USD-YEARLY ---- 0-0-None-None
# False
# 51-2005-USD-YEARLY ---- 0-0-None-None
# False
# 2848-2848-USD-YEARLY ---- 0-0-None-None
# False
# 6-1500-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# 10-6456-USD-YEARLY ---- 0-0-None-None
# False
# 222-2001-USD-YEARLY ---- 200-200-HKD-HOURLY
# False
# 25000-35000-USD-YEARLY ---- 25000-35000-THB-MONTHLY
# False
# 1-55000-USD-YEARLY ---- 30000-55000-THB-MONTHLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 1-3-USD-YEARLY ---- 0-0-None-None
# False
# 1-3-USD-YEARLY ---- 0-0-None-None
# False
# 130-130-USD-YEARLY ---- 12500-12500-PHP-MONTHLY
# False
# 2-60-USD-YEARLY ---- 28-28-NZD-HOURLY
# False
# 3-600-USD-YEARLY ---- 0-0-None-None
# False
# 3-1800-USD-YEARLY ---- 1500-1800-MYR-MONTHLY
# False
# 8-10-USD-YEARLY ---- 0-0-None-None
# False
# nton1000-nton1000-$-YEARLY ---- 27-27-AUD-HOURLY
# False
# 3-8814-USD-YEARLY ---- 0-0-None-None
# False
# 2-3-USD-YEARLY ---- 40-40-AUD-HOURLY
# False
# 23-9500-USD-YEARLY ---- 80-95-HKD-HOURLY
# False
# 6-230b-USD-YEARLY ---- 27-27-AUD-HOURLY
# False
# 3-42-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 40-3548-USD-YEARLY ---- 24-24-NZD-HOURLY
# False
# 09-19-USD-YEARLY ---- 16000-16000-PHP-MONTHLY
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 3-95-USD-YEARLY ---- 15000-80000-THB-MONTHLY
# False
# 22-24-USD-YEARLY ---- 60-70-HKD-HOURLY
# False
# 30-1500-USD-YEARLY ---- 0-0-None-None
# False
# 3-365-USD-YEARLY ---- 0-0-None-None
# False
# 6-10-USD-YEARLY ---- 52-60-HKD-HOURLY
# False
# 3-120235140-USD-YEARLY ---- 60-80-HKD-HOURLY
# False
# 21-2958-USD-YEARLY ---- 0-0-None-None
# False
# 5000-5000-USD-YEARLY ---- 0-0-None-None
# False
# 8500-9500-USD-YEARLY ---- 8500-9500-MYR-MONTHLY
# False
# 3-16485-USD-YEARLY ---- 0-0-None-None
# False
# tet4-5-USD-YEARLY ---- 0-0-None-None
# False
# 0830-1730-USD-YEARLY ---- 40000-50000-THB-MONTHLY
# False
# 35-24-USD-YEARLY ---- 53-53-HKD-HOURLY
# False
# 3-43-USD-YEARLY ---- 0-0-None-None
# False
# 1-20-USD-YEARLY ---- 37-37-AUD-HOURLY
# False
# 40-62000-USD-YEARLY ---- 62000-72000-AUD-ANNUAL
# False
# 4-12000-USD-YEARLY ---- 100-120-HKD-HOURLY
# False
# 21000-30000-USD-YEARLY ---- 21000-21000-PHP-MONTHLY
# False
# 1700-863629665-USD-YEARLY ---- 12000-18000-THB-MONTHLY
# False
# 21-21-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# 19-19-USD-YEARLY ---- 0-0-None-None
# False
# 3045-3045-USD-YEARLY ---- 30-30-AUD-HOURLY
# False
# 07-13-USD-YEARLY ---- 3750-5000-HKD-WEEKLY
# False
# 63-13125etonootonoetonet-USD-YEARLY ---- 63-131-AUD-HOURLY
# False
# 8856-8856-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 875to950-875to950-$-YEARLY ---- 875-950-SGD-WEEKLY
# False
# 2687-2687-USD-YEARLY ---- 27-27-AUD-HOURLY
# False
# 2000--USD-YEARLY ---- 2000-2700-SGD-MONTHLY
# False
# 6-302-USD-YEARLY ---- 0-0-None-None
# False
# 50-50-USD-YEARLY ---- 23-23-NZD-HOURLY
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 2497ton-2497ton-USD-YEARLY ---- 0-0-None-None
# False
# 22-24-USD-YEARLY ---- 45-60-HKD-HOURLY
# False
# 22-24-USD-YEARLY ---- 50-80-HKD-HOURLY
# False
# 2000-199859-USD-YEARLY ---- 2000-3000-SGD-MONTHLY
# False
# 3-30-USD-YEARLY ---- 30-30-SGD-HOURLY
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 22-24-USD-YEARLY ---- 65-75-HKD-HOURLY
# False
# 30-3499-$-YEARLY ---- 30-35-NZD-HOURLY
# False
# tet3-5e-USD-YEARLY ---- 0-0-None-None
# False
# 730-730-USD-YEARLY ---- 32-35-SGD-HOURLY
# False
# 917-922-USD-YEARLY ---- 125000-125000-PHP-MONTHLY
# False
# 6-20000-USD-YEARLY ---- 18000-18000-PHP-MONTHLY
# False
# 10-2302-USD-YEARLY ---- 12000-15000-MYR-MONTHLY
# False
# 4-22-USD-YEARLY ---- 80-80-HKD-HOURLY
# False
# 20-33-USD-YEARLY ---- 20-33-SGD-DAILY
# False
# 3-6-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 2000-2000-MYR-MONTHLY
# False
# 5-8841-USD-YEARLY ---- 0-0-None-None
# False
# to15000-to15000-$-YEARLY ---- 30-30-AUD-HOURLY
# False
# 5-7-USD-YEARLY ---- 0-0-None-None
# False
# 21-2958-USD-YEARLY ---- 0-0-None-None
# False
# 1-247-USD-YEARLY ---- 0-0-None-None
# False
# to5-to5-USD-YEARLY ---- 0-0-None-None
# False
# 11-24-USD-YEARLY ---- 63-63-HKD-HOURLY
# False
# 3-6453-USD-YEARLY ---- 0-0-None-None
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 22-24-USD-YEARLY ---- 65-70-HKD-HOURLY
# False
# 4-19122023-USD-YEARLY ---- 70-77-HKD-HOURLY
# False
# 50000-50000-USD-YEARLY ---- 0-0-None-None
# False
# 1-11864363-USD-YEARLY ---- 118643-118643-AUD-ANNUAL
# False
# 34-38727-USD-YEARLY ---- 31-36-AUD-HOURLY
# False
# 400-400-USD-YEARLY ---- 0-0-None-None
# False
# 1-2-USD-YEARLY ---- 0-0-None-None
# False
# 5-8-USD-YEARLY ---- 0-0-None-None
# False
# to3000b-to3000b-USD-YEARLY ---- 127607-127607-AUD-ANNUAL
# False
# between85000n119000-between85000n119000-USD-YEARLY ---- 85000-119000-AUD-ANNUAL
# False
# to5000-to5000-USD-YEARLY ---- 67357-94568-AUD-ANNUAL
# False
# 1-10ton-USD-YEARLY ---- 9000-11000-THB-MONTHLY
# False
# 2-4-USD-YEARLY ---- 25-30-NZD-HOURLY
# False
# 19-19-USD-YEARLY ---- 0-0-None-None
# False
# 6500-6122023-USD-YEARLY ---- 55-65-HKD-HOURLY
# False
# 6-20000-USD-YEARLY ---- 18000-18000-PHP-MONTHLY
# False
# 1-1-USD-YEARLY ---- 0-0-None-None
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 10-2958-USD-YEARLY ---- 0-0-None-None
# False
# 70000-10000010-USD-YEARLY ---- 2000-2500-MYR-MONTHLY
# False
# 1-522-USD-YEARLY ---- 120-120-HKD-HOURLY
# False
# 19-19-USD-YEARLY ---- 0-0-None-None
# False
# 283-3658-USD-YEARLY ---- 37-37-AUD-HOURLY
# False
# 1-50-USD-YEARLY ---- 34-50-AUD-HOURLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 7500-7500-USD-YEARLY ---- 33-33-AUD-HOURLY
# False
# 1-22102023-USD-YEARLY ---- 67357-94568-AUD-ANNUAL
# False
# 35-24-USD-YEARLY ---- 90-100-HKD-HOURLY
# False
# 3-8899-USD-YEARLY ---- 0-0-None-None
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 500-650-$-YEARLY ---- 500-650-SGD-WEEKLY
# False
# 666676-666676-USD-YEARLY ---- 0-0-None-None
# False
# 54928-54928-USD-YEARLY ---- 49-49-AUD-HOURLY
# False
# 5-2958-USD-YEARLY ---- 0-0-None-None
# False
# 150-150-USD-YEARLY ---- 0-0-None-None
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 575to875-575to875-$-YEARLY ---- 575-875-SGD-WEEKLY
# False
# 3-5-USD-YEARLY ---- 0-0-None-None
# False
# 30-2500-USD-YEARLY ---- 2500-2500-MYR-MONTHLY
# False
# 30-2021-USD-YEARLY ---- 0-0-None-None
# False
# 2-625-USD-YEARLY ---- 625-800-SGD-WEEKLY
# False
# 475-475-USD-YEARLY ---- 375-475-MYR-WEEKLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 6-9-USD-YEARLY ---- 100-127-SGD-DAILY
# False
# 22-24-USD-YEARLY ---- 70-107-HKD-HOURLY
# False
# 3-69028748-USD-YEARLY ---- 3000-4000-SGD-MONTHLY
# False
# 5-8-USD-YEARLY ---- 0-0-None-None
# False
# 1-11-USD-YEARLY ---- 500-667-PHP-DAILY
# False
# 23-21122023-USD-YEARLY ---- 60-60-HKD-HOURLY
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 2000-2400-USD-YEARLY ---- 2000-2400-SGD-MONTHLY
# False
# 2-8-USD-YEARLY ---- 25000-25000-PHP-MONTHLY
# False
# 5000-6000-USD-YEARLY ---- 50-60-AUD-HOURLY
# False
# 5903-5903-USD-YEARLY ---- 52-59-AUD-HOURLY
# False
# 25-150000-USD-YEARLY ---- 1500-2500-MYR-MONTHLY
# False
# 11-24-USD-YEARLY ---- 75-75-HKD-HOURLY
# False
# 2-2-USD-YEARLY ---- 0-0-None-None
# False
# 2-20000-USD-YEARLY ---- 18000-18000-PHP-MONTHLY
# False
# 230-900-USD-YEARLY ---- 30-30-AUD-HOURLY
# False
# 65000-80000e-$-YEARLY ---- 65000-80000-AUD-ANNUAL
# False
# 12-20000-USD-YEARLY ---- 17500-17500-PHP-MONTHLY
# False
# 23-28122023-USD-YEARLY ---- 78-78-HKD-HOURLY
# False
# tet12-24ont-$-YEARLY ---- 9-10-SGD-HOURLY
# False
# 18-50-USD-YEARLY ---- 100-250-THB-HOURLY
# False
# 21-8842-USD-YEARLY ---- 0-0-None-None
# False
# 12-1995-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 0-0-None-None ---- 850-850-HKD-HOURLY
# False
# 5-1048841-USD-YEARLY ---- 0-0-None-None
# False
# 10-2958-USD-YEARLY ---- 0-0-None-None
# False
# 569814ton-569814ton-$-YEARLY ---- 40-50-SGD-HOURLY
# False
# 37-45eo-USD-YEARLY ---- 37-45-NZD-HOURLY
# False
# 1-1-USD-YEARLY ---- 0-0-None-None
# False
# 2-84310-USD-YEARLY ---- 25000-30000-THB-MONTHLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 8-2500-USD-YEARLY ---- 1800-2500-MYR-MONTHLY
# False
# 9-120235140-USD-YEARLY ---- 50-68-HKD-HOURLY
# False
# 4000tonton-4000tonton-USD-YEARLY ---- 3500-4000-SGD-MONTHLY
# False
# 1500-2200ont-USD-YEARLY ---- 1500-2200-SGD-MONTHLY
# False
# to15900-to15900-$-YEARLY ---- 40-40-AUD-HOURLY
# False
# 3-6681-USD-YEARLY ---- 0-0-None-None
# False
# 23-120235140-USD-YEARLY ---- 65-75-HKD-HOURLY
# False
# 0830-1730-USD-YEARLY ---- 40000-50000-THB-MONTHLY
# False
# 2000-2800-USD-YEARLY ---- 2000-2800-SGD-MONTHLY
# False
# 22-24-USD-YEARLY ---- 50-80-HKD-HOURLY
# False
# 1-3-USD-YEARLY ---- 0-0-None-None
# False
# 50-60-USD-YEARLY ---- 50-60-THB-HOURLY
# False
# 3-3-USD-YEARLY ---- 17500-17500-PHP-MONTHLY
# False
# 1-1-USD-YEARLY ---- 0-0-None-None
# False
# 5-2958-USD-YEARLY ---- 0-0-None-None
# False
# 80ton-80ton-USD-YEARLY ---- 0-0-None-None
# False
# 2600-2600-USD-YEARLY ---- 26-26-NZD-HOURLY
# False
# 1000-1500-USD-YEARLY ---- 1000-1500-SGD-MONTHLY
# False
# 25000-35000-USD-YEARLY ---- 25000-35000-THB-MONTHLY
# False
# 5-2200-USD-YEARLY ---- 0-0-None-None
# False
# 14525-14525-USD-YEARLY ---- 0-0-None-None
# False
# 81-81-USD-YEARLY ---- 0-0-None-None
# False
# 18-18-USD-YEARLY ---- 0-0-None-None
# False
# 1-1-USD-YEARLY ---- 15000-20000-THB-MONTHLY
# False
# 6-1500-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# 58000-58000-USD-YEARLY ---- 0-0-None-None
# False
# 34-400-USD-YEARLY ---- 34-34-AUD-HOURLY
# False
# 4-20-USD-YEARLY ---- 0-0-None-None
# False
# 1235-1235-USD-YEARLY ---- 0-0-None-None
# False
# 30-30-USD-YEARLY ---- 28-30-AUD-HOURLY
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 2018-2018-USD-YEARLY ---- 0-0-None-None
# False
# 2-2-USD-YEARLY ---- 0-0-None-None
# False
# 7000-14000-USD-YEARLY ---- 7000-14000-SGD-MONTHLY
# False
# 2etton-2etton-USD-YEARLY ---- 117544-120393-AUD-ANNUAL
# False
# 33-3400-USD-YEARLY ---- 2600-3400-SGD-MONTHLY
# False
# 4-6-USD-YEARLY ---- 0-0-None-None
# False
# 2-2-USD-YEARLY ---- 0-0-None-None
# False
# 5-5-USD-YEARLY ---- 55-55-AUD-HOURLY
# False
# 2-4-USD-YEARLY ---- 0-0-None-None
# False
# 17-25-$-YEARLY ---- 17-25-PHP-DAILY
# False
# 127--USD-YEARLY ---- 127-150-SGD-DAILY
# False
# between85000n119000-between85000n119000-USD-YEARLY ---- 85000-119000-AUD-ANNUAL
# False
# 5-7-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 9-9679624747-USD-YEARLY ---- 19000-19000-PHP-MONTHLY
# False
# 6-6-USD-YEARLY ---- 44-44-AUD-HOURLY
# False
# 1-84374-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# 18-28-USD-YEARLY ---- 1500-5000-MYR-MONTHLY
# False
# 5-5-USD-YEARLY ---- 2300-3000-MYR-MONTHLY
# False
# tet3-5e-USD-YEARLY ---- 0-0-None-None
# False
# 83to100-83to100-$-YEARLY ---- 83-100-MYR-DAILY
# False
# 0-0-None-None ---- 30000-50000-THB-MONTHLY
# False
# 0-0-None-None ---- 1600-2400-MYR-MONTHLY
# False
# to28500-to28500-$-YEARLY ---- 42-52-AUD-HOURLY
# False
# 12-19-USD-YEARLY ---- 0-0-None-None
# False
# 25-150000-USD-YEARLY ---- 1500-2500-MYR-MONTHLY
# False
# to49eo-to49eo-USD-YEARLY ---- 28-40-AUD-HOURLY
# False
# between3405n3620-between3405n3620-$-YEARLY ---- 34-36-AUD-HOURLY
# False
# 15-18-USD-YEARLY ---- 70-80-HKD-HOURLY
# False
# 4-1200-USD-YEARLY ---- 2000-3000-MYR-MONTHLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 20-2958-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 2-60-USD-YEARLY ---- 60-60-HKD-HOURLY
# False
# 09-12-USD-YEARLY ---- 18000-18000-PHP-MONTHLY
# False
# tet1-e-USD-YEARLY ---- 0-0-None-None
# False
# 4-27122023-USD-YEARLY ---- 50-65-HKD-HOURLY
# False
# 400-400-USD-YEARLY ---- 0-0-None-None
# False
# 1-1-USD-YEARLY ---- 0-0-None-None
# False
# 730-730-USD-YEARLY ---- 0-0-None-None
# False
# 1-619-USD-YEARLY ---- 18000-21500-THB-MONTHLY
# False
# 6-1500-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# 22-24-USD-YEARLY ---- 70-70-HKD-HOURLY
# False
# 32-23-USD-YEARLY ---- 55-80-HKD-HOURLY
# False
# 4-3731-USD-YEARLY ---- 37-37-AUD-HOURLY
# False
# 19-19-USD-YEARLY ---- 0-0-None-None
# False
# 28-28-USD-YEARLY ---- 1600-1900-MYR-MONTHLY
# False
# 92-50000-USD-YEARLY ---- 24-29-AUD-HOURLY
# False
# 2-2-USD-YEARLY ---- 0-0-None-None
# False
# 11011-11011-USD-YEARLY ---- 0-0-None-None
# False
# 3-2013-USD-YEARLY ---- 48-55-AUD-HOURLY
# False
# 1-10-USD-YEARLY ---- 0-0-None-None
# False
# tet2-3e-USD-YEARLY ---- 0-0-None-None
# False
# 36-330-USD-YEARLY ---- 36-36-AUD-HOURLY
# False
# 974797-974797-USD-YEARLY ---- 0-0-None-None
# False
# to144000-to144000-USD-YEARLY ---- 59-60-AUD-HOURLY
# False
# to83-to83-$-YEARLY ---- 83-83-SGD-DAILY
# False
# 10-10-USD-YEARLY ---- 2200-2200-MYR-MONTHLY
# False
# 1-6426574-USD-YEARLY ---- 64265-64265-AUD-ANNUAL
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 1-3153-USD-YEARLY ---- 32-33-AUD-HOURLY
# False
# 67-80-$-YEARLY ---- 67-80-HKD-DAILY
# False
# 2600-3500-USD-YEARLY ---- 2600-3500-SGD-MONTHLY
# False
# 1-84374-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# 21-21-USD-YEARLY ---- 65-65-HKD-HOURLY
# False
# 09-19-USD-YEARLY ---- 25000-25000-PHP-MONTHLY
# False
# 200358-200358-USD-YEARLY ---- 100-133-PHP-DAILY
# False
# 1-1-USD-YEARLY ---- 0-0-None-None
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 10000-20000tonton-USD-YEARLY ---- 10000-20000-MYR-MONTHLY
# False
# 1800-3000-$-YEARLY ---- 1800-3000-SGD-MONTHLY
# False
# 2-3256-USD-YEARLY ---- 29-33-AUD-HOURLY
# False
# 20-1500-USD-YEARLY ---- 0-0-None-None
# False
# 9-20000-USD-YEARLY ---- 16000-16000-PHP-MONTHLY
# False
# 9-22122023-USD-YEARLY ---- 68-68-HKD-HOURLY
# False
# 22-24-USD-YEARLY ---- 50-55-HKD-HOURLY
# False
# 19-67-USD-YEARLY ---- 0-0-None-None
# False
# 4812-4812-USD-YEARLY ---- 48-48-AUD-HOURLY
# False
# 10-20000-USD-YEARLY ---- 18000-18000-PHP-MONTHLY
# False
# 200-22000-USD-YEARLY ---- 0-0-None-None
# False
# notonton2600to3400-notonton2600to3400-$-YEARLY ---- 2600-3400-SGD-MONTHLY
# False
# to3100-to3100-$-YEARLY ---- 3100-3300-SGD-MONTHLY
# False
# 33-24-USD-YEARLY ---- 60-60-HKD-HOURLY
# False
# 2800-3050nb-USD-YEARLY ---- 2800-3050-SGD-MONTHLY
# False
# 11-13-USD-YEARLY ---- 17500-17500-PHP-MONTHLY
# False
# 2-45001-USD-YEARLY ---- 0-0-None-None
# False
# 05-19-USD-YEARLY ---- 25000-25000-PHP-MONTHLY
# False
# 15-70-USD-YEARLY ---- 21-27-NZD-HOURLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 3-30000-USD-YEARLY ---- 25000-25000-PHP-MONTHLY
# False
# 2021-2021-USD-YEARLY ---- 0-0-None-None
# False
# 1-1-USD-YEARLY ---- 1500-2200-MYR-MONTHLY
# False
# 4090-4805ton-USD-YEARLY ---- 41-48-AUD-HOURLY
# False
# 3-5-USD-YEARLY ---- 0-0-None-None
# False
# 3-50000-USD-YEARLY ---- 35000-50000-THB-MONTHLY
# False
# 6-97370697-USD-YEARLY ---- 3000-3300-SGD-MONTHLY
# False
# 12-1982-USD-YEARLY ---- 2000-2000-MYR-MONTHLY
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 2-1550-USD-YEARLY ---- 23000-23000-PHP-MONTHLY
# False
# 22-24-USD-YEARLY ---- 90-90-HKD-HOURLY
# False
# 6-230000-USD-YEARLY ---- 2300-4400-MYR-MONTHLY
# False
# 3-3180-USD-YEARLY ---- 0-0-None-None
# False
# 8345-8345-USD-YEARLY ---- 0-0-None-None
# False
# 247-247-USD-YEARLY ---- 0-0-None-None
# False
# 1-3-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 6500075000-6500075000-USD-YEARLY ---- 65000-75000-AUD-ANNUAL
# False
# 930-930-USD-YEARLY ---- 20000-25000-THB-MONTHLY
# False
# 91542691ton-91542691ton-USD-YEARLY ---- 2200-3400-SGD-MONTHLY
# False
# 77-87-USD-YEARLY ---- 77-87-SGD-DAILY
# False
# 100-117-$-YEARLY ---- 100-117-SGD-DAILY
# False
# 730-530-USD-YEARLY ---- 2500-3800-SGD-MONTHLY
# False
# 3-6700-USD-YEARLY ---- 0-0-None-None
# False
# 40-2022-USD-YEARLY ---- 0-0-None-None
# False
# 4-15122023-USD-YEARLY ---- 68-68-HKD-HOURLY
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 10-08-USD-YEARLY ---- 17000-17000-PHP-MONTHLY
# False
# 8-2-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 18-27-USD-YEARLY ---- 3500-3500-MYR-MONTHLY
# False
# 1700-1700-USD-YEARLY ---- 1700-2200-MYR-MONTHLY
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 2460-2460-USD-YEARLY ---- 0-0-None-None
# False
# 10000-15000-USD-YEARLY ---- 10000-15000-MYR-MONTHLY
# False
# 11-247-USD-YEARLY ---- 0-0-None-None
# False
# 33-4459-USD-YEARLY ---- 0-0-None-None
# False
# 6nbtonton-6nbtonton-USD-YEARLY ---- 1125-1500-HKD-WEEKLY
# False
# 4-25000-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 80-117tonton-$-YEARLY ---- 80-117-PHP-DAILY
# False
# 5-6896-USD-YEARLY ---- 0-0-None-None
# False
# between3229-3375-$-YEARLY ---- 32-33-AUD-HOURLY
# False
# 4-4-USD-YEARLY ---- 0-0-None-None
# False
# 2-2-USD-YEARLY ---- 25-27-NZD-HOURLY
# False
# 19-19-USD-YEARLY ---- 0-0-None-None
# False
# 40-360-USD-YEARLY ---- 0-0-None-None
# False
# 1-5-USD-YEARLY ---- 0-0-None-None
# False
# 6-26000-USD-YEARLY ---- 23-26-NZD-HOURLY
# False
# 1000-600-USD-YEARLY ---- 150-200-HKD-HOURLY
# False
# 4-15122023-USD-YEARLY ---- 50-65-HKD-HOURLY
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 1-3-USD-YEARLY ---- 0-0-None-None
# False
# 10-6-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# tet3-5e-USD-YEARLY ---- 0-0-None-None
# False
# 1200-1900-USD-YEARLY ---- 13000-14900-HKD-MONTHLY
# False
# 1-3500-USD-YEARLY ---- 2500-3500-SGD-MONTHLY
# False
# 83-100-$-YEARLY ---- 83-100-SGD-DAILY
# False
# 6-7493-USD-YEARLY ---- 0-0-None-None
# False
# to38-to38-USD-YEARLY ---- 35-49-AUD-HOURLY
# False
# 83--$-YEARLY ---- 83-100-HKD-DAILY
# False
# 2-2-USD-YEARLY ---- 0-0-None-None
# False
# 5132-5282-USD-YEARLY ---- 51-53-NZD-HOURLY
# False
# between8959800--USD-YEARLY ---- 89598-94514-AUD-ANNUAL
# False
# 3532-4960-USD-YEARLY ---- 35-50-AUD-HOURLY
# False
# 4-111296-USD-YEARLY ---- 45-50-AUD-HOURLY
# False
# 2024-2024-USD-YEARLY ---- 0-0-None-None
# False
# 15-15-USD-YEARLY ---- 0-0-None-None
# False
# 1-28-USD-YEARLY ---- 27000-27000-PHP-MONTHLY
# False
# 4-18122023-USD-YEARLY ---- 65-75-HKD-HOURLY
# False
# 130-830-USD-YEARLY ---- 20-30-NZD-HOURLY
# False
# 6-100-USD-YEARLY ---- 100-150-MYR-DAILY
# False
# 100-100-USD-YEARLY ---- 0-0-None-None
# False
# 800-800-USD-YEARLY ---- 1700-2000-MYR-MONTHLY
# False
# 20000-20000-USD-YEARLY ---- 16000-16000-PHP-MONTHLY
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 3-5-USD-YEARLY ---- 80000-100000-THB-MONTHLY
# False
# 1-240610-USD-YEARLY ---- 123032-125547-AUD-ANNUAL
# False
# 6-6-USD-YEARLY ---- 0-0-None-None
# False
# 30-35eo-USD-YEARLY ---- 30-35-AUD-HOURLY
# False
# 1-10-USD-YEARLY ---- 26-26-NZD-HOURLY
# False
# 1-139187-USD-YEARLY ---- 89095-139187-AUD-ANNUAL
# False
# 21-24-USD-YEARLY ---- 50-60-HKD-HOURLY
# False
# to35-to35-USD-YEARLY ---- 30-35-AUD-HOURLY
# False
# 9-6-USD-YEARLY ---- 100-133-SGD-DAILY
# False
# to18550-to18550-USD-YEARLY ---- 32-32-AUD-HOURLY
# False
# 2022tone-2022tone-USD-YEARLY ---- 0-0-None-None
# False
# 4-65000-USD-YEARLY ---- 65000-75000-AUD-ANNUAL
# False
# 6-7-USD-YEARLY ---- 4500-5750-HKD-WEEKLY
# False
# between70-100-$-YEARLY ---- 70-100-AUD-HOURLY
# False
# 18000-20000-USD-YEARLY ---- 18000-18000-PHP-MONTHLY
# False
# 2460-2460-USD-YEARLY ---- 0-0-None-None
# False
# 22-24-USD-YEARLY ---- 60-60-HKD-HOURLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 67-83-USD-YEARLY ---- 67-83-SGD-DAILY
# False
# 11-27-USD-YEARLY ---- 500-667-HKD-DAILY
# False
# 2-2500-USD-YEARLY ---- 25-25-AUD-HOURLY
# False
# 011-14372485-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# tet3-8e-USD-YEARLY ---- 0-0-None-None
# False
# 3-3434-USD-YEARLY ---- 33-34-AUD-HOURLY
# False
# 10-1105066-USD-YEARLY ---- 3000-4500-SGD-MONTHLY
# False
# 8-8-USD-YEARLY ---- 0-0-None-None
# False
# 17000-20000-USD-YEARLY ---- 17000-17000-PHP-MONTHLY
# False
# 3184-3460eo-USD-YEARLY ---- 31-34-AUD-HOURLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 3-1000-USD-YEARLY ---- 600-1000-SGD-MONTHLY
# False
# 12-12-USD-YEARLY ---- 12-12-SGD-HOURLY
# False
# 2900tonb-2900tonb-USD-YEARLY ---- 2200-2900-SGD-MONTHLY
# False
# tet2-3e-USD-YEARLY ---- 0-0-None-None
# False
# 5-1048841-USD-YEARLY ---- 0-0-None-None
# False
# 2-2776-USD-YEARLY ---- 28-30-NZD-HOURLY
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 1-1-USD-YEARLY ---- 3000-3000-MYR-MONTHLY
# False
# 2023-408564-USD-YEARLY ---- 600-900-SGD-MONTHLY
# False
# 10354079to10701039-10354079to10701039-$-YEARLY ---- 103541-103541-AUD-ANNUAL
# False
# 6-2800-USD-YEARLY ---- 2800-3100-SGD-MONTHLY
# False
# 15-18-USD-YEARLY ---- 70-80-HKD-HOURLY
# False
# 2-900-USD-YEARLY ---- 0-0-None-None
# False
# 1500-2200-USD-YEARLY ---- 1500-2200-MYR-MONTHLY
# False
# 25-40-USD-YEARLY ---- 2500-7500-MYR-MONTHLY
# False
# 3-365-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-USD-YEARLY ---- 0-0-None-None
# False
# 4-2958-USD-YEARLY ---- 0-0-None-None
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 6tonton4500-7200-$-YEARLY ---- 4500-7200-SGD-MONTHLY
# False
# 22-24-USD-YEARLY ---- 55-80-HKD-HOURLY
# False
# 120-50000-USD-YEARLY ---- 0-0-None-None
# False
# 1-7000-USD-YEARLY ---- 60-70-HKD-HOURLY
# False
# 1-1-USD-YEARLY ---- 0-0-None-None
# False
# 83-113-$-YEARLY ---- 83-113-HKD-DAILY
# False
# 0-0-None-None ---- 19000-19000-PHP-MONTHLY
# False
# 16-16-USD-YEARLY ---- 1500-1800-MYR-MONTHLY
# False
# 247-41299-USD-YEARLY ---- 27-27-AUD-HOURLY
# False
# 35-24-USD-YEARLY ---- 63-73-HKD-HOURLY
# False
# 1-247-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 21-5118-USD-YEARLY ---- 0-0-None-None
# False
# 2-2-USD-YEARLY ---- 0-0-None-None
# False
# 3-3-USD-YEARLY ---- 25000-25000-PHP-MONTHLY
# False
# 4-4-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 25000-35000-HKD-MONTHLY
# False
# 21-2958-USD-YEARLY ---- 0-0-None-None
# False
# 4-670846-USD-YEARLY ---- 26-26-AUD-HOURLY
# False
# 3-500-USD-YEARLY ---- 0-0-None-None
# False
# 03-87242215-USD-YEARLY ---- 2500-4000-MYR-MONTHLY
# False
# 2025tontonnbtteton-2025tontonnbtteton-USD-YEARLY ---- 93838-93838-AUD-ANNUAL
# False
# 60-57325686-USD-YEARLY ---- 60-62-HKD-HOURLY
# False
# 11-20000-USD-YEARLY ---- 18400-18400-PHP-MONTHLY
# False
# 3-1600-USD-YEARLY ---- 1500-1600-MYR-MONTHLY
# False
# 1-15-USD-YEARLY ---- 2500-3000-MYR-MONTHLY
# False
# 1-2487-USD-YEARLY ---- 25-25-AUD-HOURLY
# False
# 500-500-USD-YEARLY ---- 0-0-None-None
# False
# 2-10-USD-YEARLY ---- 25000-25000-PHP-MONTHLY
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 8-2958-USD-YEARLY ---- 0-0-None-None
# False
# 1-1-USD-YEARLY ---- 0-0-None-None
# False
# 19-19-USD-YEARLY ---- 0-0-None-None
# False
# 730-615-USD-YEARLY ---- 20-30-AUD-HOURLY
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 15-2025-USD-YEARLY ---- 0-0-None-None
# False
# between615to530nbton-between615to530nbton-USD-YEARLY ---- 25-30-AUD-HOURLY
# False
# 100000ton-100000ton-$-YEARLY ---- 75-75-AUD-HOURLY
# False
# 1985-1985-USD-YEARLY ---- 0-0-None-None
# False
# boto2-boto2-USD-YEARLY ---- 0-0-None-None
# False
# 3250-4050tonton-USD-YEARLY ---- 3250-4050-SGD-MONTHLY
# False
# 360ton-360ton-USD-YEARLY ---- 0-0-None-None
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 600-2600-USD-YEARLY ---- 2600-3600-SGD-MONTHLY
# False
# 9940-9940-USD-YEARLY ---- 0-0-None-None
# False
# 35-35-USD-YEARLY ---- 30-35-AUD-HOURLY
# False
# 1200-60186944-USD-YEARLY ---- 65-65-HKD-HOURLY
# False
# 8-2958-USD-YEARLY ---- 0-0-None-None
# False
# 12-1159-USD-YEARLY ---- 0-0-None-None
# False
# 1500-1500-USD-YEARLY ---- 1500-1800-MYR-MONTHLY
# False
# 1700-6709-USD-YEARLY ---- 1700-2300-SGD-MONTHLY
# False
# 10-16-USD-YEARLY ---- 24000-24000-PHP-MONTHLY
# False
# 50-100-$-YEARLY ---- 50-100-SGD-HOURLY
# False
# 35-24-USD-YEARLY ---- 60-60-HKD-HOURLY
# False
# 25-4431889-USD-YEARLY ---- 1549-5701-MYR-MONTHLY
# False
# 12-12-USD-YEARLY ---- 25-30-NZD-HOURLY
# False
# 625-875-$-YEARLY ---- 625-875-USD-WEEKLY
# False
# 5-8-USD-YEARLY ---- 0-0-None-None
# False
# 3-8899-USD-YEARLY ---- 0-0-None-None
# False
# 3-5-USD-YEARLY ---- 0-0-None-None
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 3086-3192-USD-YEARLY ---- 31-32-AUD-HOURLY
# False
# 1-247-USD-YEARLY ---- 0-0-None-None
# False
# 1-25000-USD-YEARLY ---- 25000-25000-PHP-MONTHLY
# False
# 10-11-USD-YEARLY ---- 90-90-HKD-HOURLY
# False
# 3-2958-USD-YEARLY ---- 0-0-None-None
# False
# 3-2551-USD-YEARLY ---- 0-0-None-None
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 8000-8000-USD-YEARLY ---- 17500-17500-PHP-MONTHLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 1-35-USD-YEARLY ---- 0-0-None-None
# False
# 2-12-USD-YEARLY ---- 0-0-None-None
# False
# 3-5-USD-YEARLY ---- 80000-100000-THB-MONTHLY
# False
# 8-120235140-USD-YEARLY ---- 55-55-HKD-HOURLY
# False
# 1-120235140-USD-YEARLY ---- 100-100-HKD-HOURLY
# False
# 2-4920-USD-YEARLY ---- 38-49-AUD-HOURLY
# False
# 40-89-USD-YEARLY ---- 0-0-None-None
# False
# 1640-1640-USD-YEARLY ---- 1640-1640-SGD-MONTHLY
# False
# 50000-50000-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 4-4-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 9-6tonton-USD-YEARLY ---- 3200-3800-SGD-MONTHLY
# False
# 20-40-USD-YEARLY ---- 0-0-None-None
# False
# oeto40-oeto40-USD-YEARLY ---- 0-0-None-None
# False
# 58650-58650-USD-YEARLY ---- 58650-58650-NZD-ANNUAL
# False
# 800-3500-USD-YEARLY ---- 3000-3500-SGD-MONTHLY
# False
# 110-400-USD-YEARLY ---- 0-0-None-None
# False
# 23-23-USD-YEARLY ---- 65-75-HKD-HOURLY
# False
# 2-77000-USD-YEARLY ---- 55000-77000-AUD-ANNUAL
# False
# 2-2-USD-YEARLY ---- 0-0-None-None
# False
# 09-14-USD-YEARLY ---- 17500-17500-PHP-MONTHLY
# False
# 1500-2016-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 67-90-USD-YEARLY ---- 67-90-SGD-DAILY
# False
# 23-120235140-USD-YEARLY ---- 65-75-HKD-HOURLY
# False
# 17-17-USD-YEARLY ---- 2000-2500-MYR-MONTHLY
# False
# 2025-2025-USD-YEARLY ---- 0-0-None-None
# False
# 2-57-USD-YEARLY ---- 55-57-AUD-HOURLY
# False
# between2270-2825eo-USD-YEARLY ---- 20-25-NZD-HOURLY
# False
# 33-24-USD-YEARLY ---- 6240-6240-HKD-MONTHLY
# False
# 5-365-USD-YEARLY ---- 0-0-None-None
# False
# 50-2025-USD-YEARLY ---- 20-30-AUD-HOURLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 9-9-USD-YEARLY ---- 125000-125000-PHP-MONTHLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 23240943-23240943-USD-YEARLY ---- 0-0-None-None
# False
# 4-4-USD-YEARLY ---- 0-0-None-None
# False
# 18000-20000-USD-YEARLY ---- 18000-18000-PHP-MONTHLY
# False
# 1-1-USD-YEARLY ---- 0-0-None-None
# False
# 8-21-USD-YEARLY ---- 60-60-HKD-HOURLY
# False
# 1-6247-USD-YEARLY ---- 62-64-AUD-HOURLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 98868149-98868149-USD-YEARLY ---- 12000-30000-HKD-MONTHLY
# False
# 4382-4382-USD-YEARLY ---- 44-44-AUD-HOURLY
# False
# 2497ton-2497ton-USD-YEARLY ---- 0-0-None-None
# False
# 9-9-USD-YEARLY ---- 0-0-None-None
# False
# 5-8826-USD-YEARLY ---- 0-0-None-None
# False
# 1-150000-USD-YEARLY ---- 1500-2500-MYR-MONTHLY
# False
# 1-1-USD-YEARLY ---- 0-0-None-None
# False
# 2-12231-USD-YEARLY ---- 0-0-None-None
# False
# 12310490-12555729-USD-YEARLY ---- 123104-125557-AUD-ANNUAL
# False
# 0-0-None-None ---- 18000-25000-THB-MONTHLY
# False
# 5-5-USD-YEARLY ---- 50000-100000-THB-MONTHLY
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 7-3231-USD-YEARLY ---- 0-0-None-None
# False
# 5-5-USD-YEARLY ---- 35000-50000-THB-MONTHLY
# False
# 22-23-USD-YEARLY ---- 100-100-HKD-HOURLY
# False
# 5-10000-USD-YEARLY ---- 80-100-HKD-HOURLY
# False
# 60221-64571-USD-YEARLY ---- 60221-64571-AUD-ANNUAL
# False
# 2-2-USD-YEARLY ---- 0-0-None-None
# False
# 147279ton-147279ton-USD-YEARLY ---- 3000-3500-SGD-MONTHLY
# False
# 1-247-USD-YEARLY ---- 0-0-None-None
# False
# 11-24-USD-YEARLY ---- 61-61-HKD-HOURLY
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 12-12-USD-YEARLY ---- 80-80-HKD-HOURLY
# False
# 2966-20000-USD-YEARLY ---- 26-29-NZD-HOURLY
# False
# 530tonton-530tonton-$-YEARLY ---- 140-167-SGD-DAILY
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 2-2-USD-YEARLY ---- 0-0-None-None
# False
# 1250-2000175-USD-YEARLY ---- 1250-2000-SGD-WEEKLY
# False
# 8000-18122023-USD-YEARLY ---- 68-80-HKD-HOURLY
# False
# to10000-to10000-USD-YEARLY ---- 109945-109945-AUD-ANNUAL
# False
# 36-23-USD-YEARLY ---- 88-88-HKD-HOURLY
# False
# 55-60-USD-YEARLY ---- 85000-95000-AUD-ANNUAL
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 2-147510-USD-YEARLY ---- 0-0-None-None
# False
# 199859tonb-199859tonb-USD-YEARLY ---- 2600-2900-SGD-MONTHLY
# False
# 9-6-USD-YEARLY ---- 2000-3000-MYR-MONTHLY
# False
# 8-15-USD-YEARLY ---- 0-0-None-None
# False
# 247-247-USD-YEARLY ---- 0-0-None-None
# False
# 6-1500-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# 2-34-USD-YEARLY ---- 34-38-AUD-HOURLY
# False
# 900-2300-USD-YEARLY ---- 2300-2800-MYR-MONTHLY
# False
# 102-102-USD-YEARLY ---- 0-0-None-None
# False
# 5-1999-USD-YEARLY ---- 0-0-None-None
# False
# 765155-765155-USD-YEARLY ---- 13-13-AUD-HOURLY
# False
# 45-2365-USD-YEARLY ---- 23-25-NZD-HOURLY
# False
# 35-13000-USD-YEARLY ---- 90-130-HKD-HOURLY
# False
# 10-400-USD-YEARLY ---- 26-26-NZD-HOURLY
# False
# 1000-1500-USD-YEARLY ---- 1000-1500-SGD-WEEKLY
# False
# 3-1700-USD-YEARLY ---- 0-0-None-None
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 1-2025-USD-YEARLY ---- 1800-1800-MYR-MONTHLY
# False
# 7-3715-USD-YEARLY ---- 50-50-AUD-HOURLY
# False
# 1-1-USD-YEARLY ---- 0-0-None-None
# ...
# False
# 9-9-USD-YEARLY ---- 3000-4000-MYR-MONTHLY
# False
# 24-24-USD-YEARLY ---- 24-24-IDR-HOURLY
# False
# 1-1-USD-YEARLY ---- 400-500-THB-HOURLY
# False
# 3-7-USD-YEARLY ---- 0-0-None-None
# False
# 39-39-USD-YEARLY ---- 25-29-NZD-HOURLY
# False
# 2-9596-USD-YEARLY ---- 37-37-AUD-HOURLY
# False
# 1-120235140-USD-YEARLY ---- 60-65-HKD-HOURLY
# False
# 16-600-USD-YEARLY ---- 0-0-None-None
# False
# 9201ton-9201ton-USD-YEARLY ---- 50-60-HKD-HOURLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 6100-6100-USD-YEARLY ---- 500-667-HKD-DAILY
# False
# 22-24-USD-YEARLY ---- 70-75-HKD-HOURLY
# False
# 2-3-USD-YEARLY ---- 0-0-None-None
# False
# 562022-562022-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 150-200-HKD-HOURLY
# False
# 3000-3000-USD-YEARLY ---- 3000-4000-SGD-MONTHLY
# False
# 2800--$-YEARLY ---- 2800-4500-SGD-MONTHLY
# False
# 70-4550-USD-YEARLY ---- 0-0-None-None
# False
# 10-6193-USD-YEARLY ---- 0-0-None-None
# False
# 8-10-USD-YEARLY ---- 0-0-None-None
# False
# 232-3558-USD-YEARLY ---- 38-38-AUD-HOURLY
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 6-2024-USD-YEARLY ---- 3200000-3200000-IDR-MONTHLY
# False
# 2908-3300-USD-YEARLY ---- 29-33-AUD-HOURLY
# False
# 2-180-USD-YEARLY ---- 36-36-AUD-HOURLY
# False
# 3-23-USD-YEARLY ---- 0-0-None-None
# False
# oetonton2900-3400-$-YEARLY ---- 2100-3400-SGD-MONTHLY
# False
# 12923588-12923588-USD-YEARLY ---- 129236-129236-AUD-ANNUAL
# False
# 9-22-USD-YEARLY ---- 75-75-HKD-HOURLY
# False
# 200-2750-USD-YEARLY ---- 28-28-NZD-HOURLY
# False
# 3-20000-USD-YEARLY ---- 20000-20000-PHP-MONTHLY
# False
# 3-1350-USD-YEARLY ---- 14-14-SGD-HOURLY
# False
# 2-210492-USD-YEARLY ---- 5000-6000-SGD-MONTHLY
# False
# 2650-15900-USD-YEARLY ---- 31-40-AUD-HOURLY
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 6735732-9456844-USD-YEARLY ---- 67357-94568-AUD-ANNUAL
# False
# 7095689-10120898-USD-YEARLY ---- 70957-101209-AUD-ANNUAL
# False
# 8-10000-USD-YEARLY ---- 56-77-AUD-HOURLY
# False
# 13-24-USD-YEARLY ---- 70-70-HKD-HOURLY
# False
# 31-24-USD-YEARLY ---- 45-45-HKD-HOURLY
# False
# 0-0-None-None ---- 1500-1500-MYR-MONTHLY
# False
# 23-23-USD-YEARLY ---- 65-65-HKD-HOURLY
# False
# 8292800-11792800-$-YEARLY ---- 82928-117928-NZD-ANNUAL
# False
# 0-0-None-None ---- 1500-1800-MYR-MONTHLY
# False
# to15900-to15900-USD-YEARLY ---- 27-33-AUD-HOURLY
# False
# 800-800-$-YEARLY ---- 60-70-HKD-HOURLY
# False
# 43-43-USD-YEARLY ---- 0-0-None-None
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 3-12-USD-YEARLY ---- 60-80-HKD-HOURLY
# False
# 24-35-USD-YEARLY ---- 2500-3000-MYR-MONTHLY
# False
# 5-39725813-USD-YEARLY ---- 0-0-None-None
# False
# 900-30000-USD-YEARLY ---- 20000-30000-THB-MONTHLY
# False
# 2500-200358-USD-YEARLY ---- 2500-3500-SGD-MONTHLY
# False
# 9-12-USD-YEARLY ---- 48-50-HKD-HOURLY
# False
# 8-10-USD-YEARLY ---- 0-0-None-None
# False
# 16-2022-USD-YEARLY ---- 0-0-None-None
# False
# 1-150000-USD-YEARLY ---- 1500-2500-MYR-MONTHLY
# False
# tet1-2e-USD-YEARLY ---- 2500-3000-SGD-MONTHLY
# False
# 67-83-$-YEARLY ---- 67-83-MYR-DAILY
# False
# 8-8-USD-YEARLY ---- 0-0-None-None
# False
# 21-330-USD-YEARLY ---- 24-24-NZD-HOURLY
# False
# 730-1200-USD-YEARLY ---- 25-30-NZD-HOURLY
# False
# 9555-9555-USD-YEARLY ---- 0-0-None-None
# False
# 18-28-USD-YEARLY ---- 1200-5000-MYR-MONTHLY
# False
# 2-2-USD-YEARLY ---- 67500-67500-AUD-ANNUAL
# False
# 21-2958-USD-YEARLY ---- 0-0-None-None
# False
# 10-2958-USD-YEARLY ---- 0-0-None-None
# False
# 1-1-USD-YEARLY ---- 0-0-None-None
# False
# 7-9146-USD-YEARLY ---- 0-0-None-None
# False
# 2497ton-2497ton-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 27-16000-USD-YEARLY ---- 0-0-None-None
# False
# 12-2021-USD-YEARLY ---- 0-0-None-None
# False
# 24-2133-USD-YEARLY ---- 0-0-None-None
# False
# 2-2-USD-YEARLY ---- 0-0-None-None
# False
# 3000-3000-USD-YEARLY ---- 3000-3500-SGD-MONTHLY
# False
# 10-14-USD-YEARLY ---- 333-500-HKD-DAILY
# False
# 2521-2586-USD-YEARLY ---- 25-26-AUD-HOURLY
# False
# 03-74920818-USD-YEARLY ---- 1500-2000-MYR-MONTHLY
# False
# 1-1-USD-YEARLY ---- 0-0-None-None
# False
# 253-253-USD-YEARLY ---- 0-0-None-None
# False
# 5-5-USD-YEARLY ---- 2000-3000-SGD-MONTHLY
# False
# 2-15000-USD-YEARLY ---- 100-150-HKD-HOURLY
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 16-16-USD-YEARLY ---- 1500-1800-MYR-MONTHLY
# False
# 1-1-USD-YEARLY ---- 2200-2500-MYR-MONTHLY
# False
# 0-0-None-None ---- 3000-4500-MYR-MONTHLY
# False
# 2-2-USD-YEARLY ---- 0-0-None-None
# False
# 117-200tonton-$-YEARLY ---- 117-200-SGD-DAILY
# False
# 3-10000-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# 21-180000-USD-YEARLY ---- 160000-180000-AUD-ANNUAL
# False
# 1-18-USD-YEARLY ---- 1500-1800-MYR-MONTHLY
# False
# 35043-35043-USD-YEARLY ---- 1800-2300-MYR-MONTHLY
# False
# 8-8-USD-YEARLY ---- 0-0-None-None
# False
# 3-3-USD-YEARLY ---- 2200-2800-MYR-MONTHLY
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 2-7-USD-YEARLY ---- 0-0-None-None
# False
# 3-1800-USD-YEARLY ---- 1500-1800-MYR-MONTHLY
# False
# 1-1-USD-YEARLY ---- 0-0-None-None
# False
# 12-2023-USD-YEARLY ---- 2000-3000-MYR-MONTHLY
# False
# 1200000-2500000-USD-YEARLY ---- 12000-25000-THB-MONTHLY
# False
# 22-24-USD-YEARLY ---- 60-60-HKD-HOURLY
# False
# 16-16-USD-YEARLY ---- 1500-1800-MYR-MONTHLY
# False
# 2-800-USD-YEARLY ---- 0-0-None-None
# False
# 3000-3000-USD-YEARLY ---- 3000-4500-SGD-MONTHLY
# False
# 16-16-USD-YEARLY ---- 1500-1800-MYR-MONTHLY
# False
# 1-2024-USD-YEARLY ---- 70-90-MYR-HOURLY
# False
# 3-130-USD-YEARLY ---- 130-130-THB-HOURLY
# False
# bototon2-bototon2-USD-YEARLY ---- 0-0-None-None
# False
# 2-10-USD-YEARLY ---- 0-0-None-None
# False
# 2867ton-2867ton-USD-YEARLY ---- 26-29-NZD-HOURLY
# False
# 4-6050-USD-YEARLY ---- 48-60-HKD-HOURLY
# False
# 9-6ton-USD-YEARLY ---- 825-1000-SGD-WEEKLY
# False
# 16-16-USD-YEARLY ---- 1500-1800-MYR-MONTHLY
# False
# 15-322-USD-YEARLY ---- 1700-1800-MYR-MONTHLY
# False
# 75-26366323-USD-YEARLY ---- 70-75-HKD-HOURLY
# False
# 4000-5000-USD-YEARLY ---- 4000-5000-SGD-MONTHLY
# False
# 3-5-USD-YEARLY ---- 0-0-None-None
# False
# 65000-95000-USD-YEARLY ---- 65000-95000-THB-MONTHLY
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 1-9828-USD-YEARLY ---- 0-0-None-None
# False
# 1-2500-USD-YEARLY ---- 2000-2500-SGD-MONTHLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 283-283-USD-YEARLY ---- 150-283-SGD-DAILY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# to10000-to10000-USD-YEARLY ---- 67357-94568-AUD-ANNUAL
# False
# 7-10-USD-YEARLY ---- 0-0-None-None
# False
# 6735732-9456844-USD-YEARLY ---- 67357-94568-AUD-ANNUAL
# False
# 2-2-USD-YEARLY ---- 0-0-None-None
# False
# 257-000257-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 230to945ton-230to945ton-USD-YEARLY ---- 31-31-AUD-HOURLY
# False
# tet2-3e-USD-YEARLY ---- 0-0-None-None
# False
# 10-4364-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 8-3001-USD-YEARLY ---- 30-30-AUD-HOURLY
# False
# 200-8000-USD-YEARLY ---- 0-0-None-None
# False
# 1-18-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# 0-0-None-None ---- 1500-1800-SGD-MONTHLY
# False
# 20-20-USD-YEARLY ---- 0-0-None-None
# False
# to3000-to3000-USD-YEARLY ---- 67357-94568-AUD-ANNUAL
# False
# 2-9461-USD-YEARLY ---- 37-46-NZD-HOURLY
# False
# 19-19-USD-YEARLY ---- 0-0-None-None
# False
# 5-3071-USD-YEARLY ---- 31-31-AUD-HOURLY
# False
# 2365-2500-USD-YEARLY ---- 24-25-NZD-HOURLY
# False
# 1-15-USD-YEARLY ---- 2500-3000-MYR-MONTHLY
# False
# 13559123-13811146e-USD-YEARLY ---- 135591-138111-AUD-ANNUAL
# False
# 20-5000-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# 11-20000-USD-YEARLY ---- 16000-16000-PHP-MONTHLY
# False
# 4993ton-4993ton-USD-YEARLY ---- 0-0-None-None
# False
# 830-600-USD-YEARLY ---- 2000-2200-SGD-MONTHLY
# False
# 55-750-USD-YEARLY ---- 625-750-SGD-WEEKLY
# False
# 1-3-USD-YEARLY ---- 2500-3300-MYR-MONTHLY
# False
# 150-150-USD-YEARLY ---- 0-0-None-None
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 900-900-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 36000-36000-PHP-MONTHLY
# False
# 2-3-USD-YEARLY ---- 0-0-None-None
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 7-8896-USD-YEARLY ---- 800-800-SGD-MONTHLY
# False
# 87500-100000-$-YEARLY ---- 875-1000-SGD-WEEKLY
# False
# 62400--$-YEARLY ---- 2400-3000-SGD-MONTHLY
# False
# 10-2958-USD-YEARLY ---- 0-0-None-None
# False
# 3000-3500-$-YEARLY ---- 3000-3500-SGD-MONTHLY
# False
# 19-4702016-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# to10000-to10000-USD-YEARLY ---- 111673-121301-AUD-ANNUAL
# False
# 6-20000-USD-YEARLY ---- 17000-17000-PHP-MONTHLY
# False
# 1-5-USD-YEARLY ---- 120000-120000-THB-MONTHLY
# False
# 50-50-USD-YEARLY ---- 21-21-NZD-HOURLY
# False
# 2-2-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 4750-4750-HKD-WEEKLY
# False
# 53-56-USD-YEARLY ---- 53-63-HKD-HOURLY
# False
# 65-65-USD-YEARLY ---- 45-65-HKD-HOURLY
# False
# 30-38-USD-YEARLY ---- 30-38-AUD-HOURLY
# False
# 4-4-USD-YEARLY ---- 43-43-AUD-HOURLY
# False
# 1-1-USD-YEARLY ---- 2200-4000-MYR-MONTHLY
# False
# 2-257-USD-YEARLY ---- 85-85-AUD-HOURLY
# False
# 1188-2551-USD-YEARLY ---- 0-0-None-None
# False
# 1800-1800-USD-YEARLY ---- 1800-2000-MYR-MONTHLY
# False
# 6-1500-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# 1-70009000-$-YEARLY ---- 70-90-HKD-HOURLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 7000etone-7000etone-USD-YEARLY ---- 4000-7000-SGD-MONTHLY
# False
# 5-5-USD-YEARLY ---- 0-0-None-None
# False
# 2-2-USD-YEARLY ---- 0-0-None-None
# False
# 232024-232024-USD-YEARLY ---- 2800-4000-SGD-MONTHLY
# False
# 2497ton-2497ton-USD-YEARLY ---- 0-0-None-None
# False
# 3-25000-USD-YEARLY ---- 25-30-NZD-HOURLY
# False
# 247-247-USD-YEARLY ---- 0-0-None-None
# False
# 3-3915-USD-YEARLY ---- 0-0-None-None
# False
# 6000-6000-USD-YEARLY ---- 4000-6000-SGD-MONTHLY
# False
# 3142-3142-USD-YEARLY ---- 31-31-AUD-HOURLY
# False
# 2-20-USD-YEARLY ---- 48-48-AUD-HOURLY
# False
# 2-12-USD-YEARLY ---- 0-0-None-None
# False
# 20000-20000-USD-YEARLY ---- 18400-18400-PHP-MONTHLY
# False
# 3058-3058-USD-YEARLY ---- 31-31-AUD-HOURLY
# False
# 0-0-None-None ---- 27-30-NZD-HOURLY
# False
# 5-8829-USD-YEARLY ---- 0-0-None-None
# False
# 2-2-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 8-8-USD-YEARLY ---- 0-0-None-None
# False
# 2024nbton-2024nbton-USD-YEARLY ---- 55000-60000-AUD-ANNUAL
# False
# nton15-nton15-USD-YEARLY ---- 89095-139187-AUD-ANNUAL
# False
# 19-19-USD-YEARLY ---- 0-0-None-None
# False
# 10-2958-USD-YEARLY ---- 0-0-None-None
# False
# 175-175-USD-YEARLY ---- 0-0-None-None
# False
# 3-2958-USD-YEARLY ---- 0-0-None-None
# False
# to9000-to9000-USD-YEARLY ---- 105093-108612-AUD-ANNUAL
# False
# 8-2958-USD-YEARLY ---- 0-0-None-None
# False
# 6-15-USD-YEARLY ---- 25000-25000-PHP-MONTHLY
# False
# 10-8813-USD-YEARLY ---- 0-0-None-None
# False
# 3-830-USD-YEARLY ---- 1800-2000-MYR-MONTHLY
# False
# 2-9596-USD-YEARLY ---- 55-55-AUD-HOURLY
# False
# 27001-27001-USD-YEARLY ---- 0-0-None-None
# False
# 11293-11293-USD-YEARLY ---- 0-0-None-None
# False
# 16-1000-USD-YEARLY ---- 30-32-AUD-HOURLY
# False
# 8-2958-USD-YEARLY ---- 0-0-None-None
# False
# 2-15-USD-YEARLY ---- 17500-17500-PHP-MONTHLY
# False
# 1-38-USD-YEARLY ---- 105093-108612-AUD-ANNUAL
# False
# 24-24-USD-YEARLY ---- 24-24-NZD-HOURLY
# False
# 3-3-USD-YEARLY ---- 4000-5500-MYR-MONTHLY
# False
# 100-250-USD-YEARLY ---- 150-200-THB-HOURLY
# False
# 250-250-USD-YEARLY ---- 0-0-None-None
# False
# 3-7890-USD-YEARLY ---- 0-0-None-None
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 2050-2050-USD-YEARLY ---- 0-0-None-None
# False
# 6-1500-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# 200-200-USD-YEARLY ---- 41-50-NZD-HOURLY
# False
# 0-0-None-None ---- 39-39-AUD-HOURLY
# False
# 21-2958-USD-YEARLY ---- 0-0-None-None
# False
# 90000-130000-USD-YEARLY ---- 90000-130000-AUD-ANNUAL
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 4176-4308-USD-YEARLY ---- 42-43-AUD-HOURLY
# False
# 21-8842-USD-YEARLY ---- 0-0-None-None
# False
# 500to625-500to625-$-YEARLY ---- 500-625-HKD-WEEKLY
# False
# 3-60378906285-USD-YEARLY ---- 0-0-None-None
# False
# 2000-2000-USD-YEARLY ---- 2000-2800-SGD-MONTHLY
# False
# 4360-4748-USD-YEARLY ---- 44-47-AUD-HOURLY
# False
# 26151-1449-USD-YEARLY ---- 1500-2345-MYR-MONTHLY
# False
# 20000-20000-USD-YEARLY ---- 16000-16000-PHP-MONTHLY
# False
# 500-1000-USD-YEARLY ---- 500-4000-SGD-MONTHLY
# False
# 10-6-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 36-23-USD-YEARLY ---- 52-55-HKD-HOURLY
# False
# 3-3915-USD-YEARLY ---- 0-0-None-None
# False
# 5-9963692-USD-YEARLY ---- 1000-1000-THB-MONTHLY
# False
# 10-2958-USD-YEARLY ---- 0-0-None-None
# False
# 2-55-USD-YEARLY ---- 1500-3000-MYR-MONTHLY
# False
# to10000-to10000-USD-YEARLY ---- 63130-68599-AUD-ANNUAL
# False
# 3000-3000-USD-YEARLY ---- 25-30-NZD-HOURLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 2023ton-2023ton-USD-YEARLY ---- 28-28-NZD-HOURLY
# False
# to9000-to9000-USD-YEARLY ---- 105093-108612-AUD-ANNUAL
# False
# 50000-50000-USD-YEARLY ---- 0-0-None-None
# False
# between85000n119000-between85000n119000-USD-YEARLY ---- 85000-119000-AUD-ANNUAL
# False
# 1-1-USD-YEARLY ---- 0-0-None-None
# False
# 575-650-$-YEARLY ---- 575-650-SGD-WEEKLY
# False
# 30-3000-USD-YEARLY ---- 2000-3000-MYR-MONTHLY
# False
# 1-12387036-USD-YEARLY ---- 123870-127316-AUD-ANNUAL
# False
# 3-3-USD-YEARLY ---- 0-0-None-None
# False
# 4-25000-USD-YEARLY ---- 0-0-None-None
# False
# 150-200-$-YEARLY ---- 150-200-HKD-DAILY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# between25n27ee-between25n27ee-$-YEARLY ---- 25-27-NZD-HOURLY
# False
# to5000-to5000-USD-YEARLY ---- 54-54-AUD-HOURLY
# False
# 2-15000-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# 6tonb-6tonb-USD-YEARLY ---- 2800-3800-SGD-MONTHLY
# False
# 1200ton-1200ton-USD-YEARLY ---- 39-49-AUD-HOURLY
# False
# 25-25-USD-YEARLY ---- 0-0-None-None
# False
# 2-2-USD-YEARLY ---- 0-0-None-None
# False
# 3-2022-USD-YEARLY ---- 0-0-None-None
# False
# noteeoton35-42eo-USD-YEARLY ---- 35-42-AUD-HOURLY
# False
# 2-2-USD-YEARLY ---- 4000-6000-MYR-MONTHLY
# False
# to15900ton-to15900ton-USD-YEARLY ---- 49-53-AUD-HOURLY
# False
# 21-50000-USD-YEARLY ---- 0-0-None-None
# False
# 25-35-USD-YEARLY ---- 0-0-None-None
# False
# 185-24000-USD-YEARLY ---- 0-0-None-None
# False
# to9000-to9000-$-YEARLY ---- 70944-82899-AUD-ANNUAL
# False
# 23-23-USD-YEARLY ---- 62-65-HKD-HOURLY
# False
# 25000-30000-USD-YEARLY ---- 25000-25000-PHP-MONTHLY
# False
# 6-2024-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# 1-9916-USD-YEARLY ---- 1-2-HKD-MONTHLY
# False
# 5-35-USD-YEARLY ---- 1500-2000-MYR-MONTHLY
# False
# 36-3860eo-$-HOURLY ---- 36-38-AUD-HOURLY
# False
# 6-8-USD-YEARLY ---- 45-60-HKD-HOURLY
# False
# 10-10-USD-YEARLY ---- 0-0-None-None
# False
# 2500-2500-USD-YEARLY ---- 1800-2500-SGD-MONTHLY
# False
# 10555300-12865300-USD-YEARLY ---- 117544-120393-AUD-ANNUAL
# False
# 4-4000-USD-YEARLY ---- 4000-5000-SGD-MONTHLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 6300-18122023-USD-YEARLY ---- 55-63-HKD-HOURLY
# False
# 5-700-USD-YEARLY ---- 700-700-SGD-MONTHLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# to73-77-USD-YEARLY ---- 73-77-SGD-DAILY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 8-4934-USD-YEARLY ---- 0-0-None-None
# False
# 500-30000-USD-YEARLY ---- 25000-25000-PHP-MONTHLY
# False
# 1629-943609-USD-YEARLY ---- 0-0-None-None
# False
# 1-2775-USD-YEARLY ---- 28-28-AUD-HOURLY
# False
# 3-875-USD-YEARLY ---- 875-875-SGD-WEEKLY
# False
# 0-0-None-None ---- 2500-3000-MYR-MONTHLY
# False
# 20-28-USD-YEARLY ---- 1500-1500-MYR-MONTHLY
# False
# 50-60o-USD-YEARLY ---- 0-0-None-None
# False
# 5-29-USD-YEARLY ---- 29-29-NZD-HOURLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 32-24-USD-YEARLY ---- 100-100-HKD-HOURLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 100-90000-$-YEARLY ---- 90000-100000-AUD-ANNUAL
# False
# 1-56-USD-YEARLY ---- 1900-2100-MYR-MONTHLY
# False
# tet7-10e-USD-YEARLY ---- 0-0-None-None
# False
# 20-20-USD-YEARLY ---- 0-0-None-None
# False
# 451-14454-USD-YEARLY ---- 0-0-None-None
# False
# 3-95-USD-YEARLY ---- 15000-80000-THB-MONTHLY
# False
# 16104200-18014300-USD-YEARLY ---- 161042-180143-AUD-ANNUAL
# False
# 0-0-None-None ---- 0-0-None-None
# True
# 0-0-None-None ---- 0-0-None-None
# True
# 0-0-None-None ---- 85000-90000-AUD-ANNUAL
# False
# 2-2-USD-YEARLY ---- 40-40-AUD-HOURLY
# False
# 10-24160-USD-YEARLY ---- 0-0-None-None
# False
# 3-20000-USD-YEARLY ---- 17500-17500-PHP-MONTHLY
# False
# 1-30062025-USD-YEARLY ---- 81581-108532-AUD-ANNUAL
# False
# tet3-5-USD-YEARLY ---- 0-0-None-None
# False
# 2-20000-USD-YEARLY ---- 18000-18000-PHP-MONTHLY
# False
# 2020-2020-USD-YEARLY ---- 0-0-None-None
# False
# to2400-to2400-USD-YEARLY ---- 2000-2400-SGD-MONTHLY
# False
# 10-10-USD-YEARLY ---- 0-0-None-None
# False
# 3-51-USD-YEARLY ---- 0-0-None-None
# False
# 8-9362-USD-YEARLY ---- 0-0-None-None
# False
# 5-6-USD-YEARLY ---- 2500-3000-SGD-MONTHLY
# False
# 0-0-None-None ---- 0-0-None-None
# True
# count: 2267
# result: 115
# correctly indentified: 0.050727834142037936

# %% [markdown]
# Testing on Test set for salary extraction

# %%
# TEST set
import pandas as pd
salary_test = pd.read_csv(file_location['salary_labelled_test_set.csv'])

results = 0
count = 0


for index, row in salary_test.iterrows(): # Iterate through the rows of the dataframe
    predicted_label = extract_salary(row['job_ad_details'])
    true_label =  row['y_true']

    #print(predicted_label, '----', true_label)
    #print(predicted_label == true_label)
    if predicted_label == true_label:
        results += 1
    count += 1

print("count:", count)
print("result:", results)
print("correctly indentified:", results/count)
# Out:
# count: 567
# result: 25
# correctly indentified: 0.04409171075837742
